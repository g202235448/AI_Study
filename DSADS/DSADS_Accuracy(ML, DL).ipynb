# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
features = pd.read_csv("C:/HAR/DSADS/DSA.csv", index_col=0)

# %%
features
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 8635     9.298029     32.4980     -6.0782  134.634624   11.603216
# 8636     8.738784     34.0480     -6.7822  145.225186   12.050941
# 8637     9.404261     34.8670     -5.3331  130.142955   11.408022
# 8638     9.139112     32.5060     -6.8835  135.812815   11.653876
# 8639     8.868404     30.9070     -6.7151  128.743919   11.346538
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150     1.18320     0.99744    0.002208  ...
# 1        0.552416     1.140865     1.21290     1.05810    0.000784  ...
# 2        0.100538     1.140962     1.21280     1.07960    0.000508  ...
# 3       -0.231914     1.165260     1.31700     1.07870    0.002173  ...
# 4        2.042285     1.187504     1.25740     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 8635     0.570723    -2.592341     1.73230   -12.91800    9.207424  ...
# 8636     0.760224    -2.417799     1.19030   -10.90200    9.233904  ...
# 8637     0.560963    -2.408945     0.81347    -8.21750    6.635468  ...
# 8638     0.589304    -2.359531     1.32350    -9.57930    7.510565  ...
# 8639     0.585457    -2.144665     0.93113    -8.52640    6.022491  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0     6.267229e-07     0.000792      0.177075     -0.057119    -0.054963
# 1     7.403458e-07     0.000860     -0.286918     -0.057268    -0.054945
# 2     5.802523e-07     0.000762     -0.134430     -0.057068    -0.054711
# 3     5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 4     6.787533e-07     0.000824     -0.148229     -0.055801    -0.053313
# ...            ...          ...           ...           ...          ...
# 8635  9.303061e-04     0.030501      0.334449      0.625187     0.691300
# 8636  9.968638e-04     0.031573      0.396417      0.624749     0.693560
# 8637  9.194098e-04     0.030322      0.524964      0.631822     0.690120
# 8638  5.788992e-04     0.024060      0.301200      0.624196     0.688560
# 8639  5.366838e-04     0.023166      0.395776      0.633913     0.692860
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0       -0.059241  6.778722e-07     0.000823      0.036729   sitting
# 1       -0.059589  7.032302e-07     0.000839      0.347471   sitting
# 2       -0.059065  6.268222e-07     0.000792      0.045579   sitting
# 3       -0.058310  8.011245e-07     0.000895      0.240690   sitting
# 4       -0.057815  6.853423e-07     0.000828      0.258429   sitting
# ...           ...           ...          ...           ...       ...
# 8635     0.571870  9.188517e-04     0.030313      0.274486   jumping
# 8636     0.570400  9.632708e-04     0.031037      0.433661   jumping
# 8637     0.581970  8.933477e-04     0.029889      0.335023   jumping
# 8638     0.573620  1.025797e-03     0.032028      0.272121   jumping
# 8639     0.586420  9.165240e-04     0.030274      0.342332   jumping
#
# [5760 rows x 271 columns]

# %%
features['activity'].value_counts()
# Out:
# activity
# sitting                    480
# standing                   480
# lyingBack                  480
# lyingRigh                  480
# ascendingStairs            480
# decendingStairs            480
# walkingLot                 480
# walkingTreadmillFlat       480
# walkingTreadmillIncline    480
# runningTreadmill           480
# crossTrainer               480
# jumping                    480
# Name: count, dtype: int64

# %%
indexes = features[(features['activity'] == 'crossTrainer')].index
features.drop(indexes , inplace=True)

# %% [markdown]
# # Features

# %%
features['activity'].value_counts().plot(kind='bar', title='Training examples by activity type');

# %% [markdown]
# # Data Split

# %%
# X_data

# %%
X_Mild = features.loc[(features['activity']=='sitting') | (features['activity']=='standing') |
                      (features['activity']=='lyingBack') | (features['activity']=='lyingRigh')]
X_Mild = X_Mild.drop('activity', axis=1)
X_Mild
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
#
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 5280     0.379205     0.678977     5.28310     -4.5623    2.780052  ...
# 5281     1.113582     0.514644     7.77950     -9.9735    8.091228  ...
# 5282     0.709851     0.370180     6.89530    -10.0980    5.887290  ...
# 5283     0.723478     0.584968    14.26200     -8.9167    8.363776  ...
# 5284     1.374341     0.180590     6.49800     -9.9350    7.153284  ...
# ...           ...          ...         ...         ...         ...  ...
# 8635     0.570723    -2.592341     1.73230    -12.9180    9.207424  ...
# 8636     0.760224    -2.417799     1.19030    -10.9020    9.233904  ...
# 8637     0.560963    -2.408945     0.81347     -8.2175    6.635468  ...
# 8638     0.589304    -2.359531     1.32350     -9.5793    7.510565  ...
# 8639     0.585457    -2.144665     0.93113     -8.5264    6.022491  ...
#
#       LL_ymag_min  LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  \
# 5280      0.22858     0.020181     0.142059     -0.662979      0.089157
# 5281      0.19029     0.019983     0.141363     -0.543506      0.088145
# 5282      0.21293     0.021483     0.146572     -0.698457      0.112958
# 5283      0.20368     0.022426     0.149753     -0.532578      0.109216
# 5284      0.19456     0.022674     0.150579     -0.547194      0.089432
# ...           ...          ...          ...           ...           ...
# 8635      0.14186     0.000930     0.030501      0.334449      0.625187
# 8636      0.12817     0.000997     0.031573      0.396417      0.624749
# 8637      0.11760     0.000919     0.030322      0.524964      0.631822
# 8638      0.11687     0.000579     0.024060      0.301200      0.624196
# 8639      0.12082     0.000537     0.023166      0.395776      0.633913
#
#       LL_zmag_max  LL_zmag_min  LL_zmag_var  LL_zmag_std  LL_zmag_skew
# 5280      0.20032     0.011551     0.001772     0.042100      0.223807
# 5281      0.19114     0.006466     0.002118     0.046019      0.079606
# 5282      0.26419     0.013210     0.003030     0.055050      0.299435
# 5283      0.21940     0.012917     0.003016     0.054916      0.066098
# 5284      0.20654     0.001637     0.002310     0.048066      0.486886
# ...           ...          ...          ...          ...           ...
# 8635      0.69130     0.571870     0.000919     0.030313      0.274486
# 8636      0.69356     0.570400     0.000963     0.031037      0.433661
# 8637      0.69012     0.581970     0.000893     0.029889      0.335023
# 8638      0.68856     0.573620     0.001026     0.032028      0.272121
# 8639      0.69286     0.586420     0.000917     0.030274      0.342332
#
# [960 rows x 270 columns]

# %%
# y_data

# %%
y_Mild = features['activity'].loc[(features['activity']=='sitting') | (features['activity']=='standing') |
                            (features['activity']=='lyingBack') | (features['activity']=='lyingRigh')] 
y_Mild
# Out:
# 0         sitting
# 1         sitting
# 2         sitting
# 3         sitting
# 4         sitting
#           ...
# 1915    lyingRigh
# 1916    lyingRigh
# 1917    lyingRigh
# 1918    lyingRigh
# 1919    lyingRigh
# Name: activity, Length: 1920, dtype: object

# %%
y_Medium = features['activity'].loc[(features['activity']=='ascendingStairs') | (features['activity']=='decendingStairs') |
                                    (features['activity']=='walkingLot') | (features['activity']=='walkingTreadmillFlat') |
                                    (features['activity']=='walkingTreadmillIncline')] 
y_Medium
# Out:
# 1920            ascendingStairs
# 1921            ascendingStairs
# 1922            ascendingStairs
# 1923            ascendingStairs
# 1924            ascendingStairs
#                  ...
# 5275    walkingTreadmillIncline
# 5276    walkingTreadmillIncline
# 5277    walkingTreadmillIncline
# 5278    walkingTreadmillIncline
# 5279    walkingTreadmillIncline
# Name: activity, Length: 2400, dtype: object

# %%
y_Strong = features['activity'].loc[(features['activity']=='runningTreadmill') | (features['activity']=='jumping')] 
y_Strong
# Out:
# 5280    runningTreadmill
# 5281    runningTreadmill
# 5282    runningTreadmill
# 5283    runningTreadmill
# 5284    runningTreadmill
#               ...
# 8635             jumping
# 8636             jumping
# 8637             jumping
# 8638             jumping
# 8639             jumping
# Name: activity, Length: 960, dtype: object

# %% [markdown]
# ## Mild

# %%
##x,y,z dont have the same variance so we need to scale the data 
#Standardized data:

from sklearn.preprocessing import StandardScaler

X = X_Mild[["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"]]

y = y_Mild
              
scaler = StandardScaler()
X = scaler.fit_transform(X)

scaled_X = pd.DataFrame(data = X, columns = ["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"])
scaled_X['label'] = y.values

scaled_X
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        0.773353    0.783192    0.742944    0.496346    1.929421
# 1        0.773820    0.786096    0.773382    0.185542    1.094447
# 2        0.772465    0.769500    0.773345   -0.016943    0.304717
# 3        0.766481    0.773599    0.744384    0.013535    0.449562
# 4        0.761051    0.777679    0.770613   -0.078258   -0.045389
# ...           ...         ...         ...         ...         ...
# 1915    -0.213095   -0.227856   -0.197180   -0.148292   -0.742386
# 1916    -0.214399   -0.228224   -0.198583   -0.147937   -0.735455
# 1917    -0.214155   -0.228151   -0.201554   -0.145686   -0.694309
# 1918    -0.213157   -0.227912   -0.199210   -0.147536   -0.727791
# 1919    -0.214005   -0.224236   -0.200078   -0.143255   -0.654139
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.035442     0.974338    0.963600    0.990423   -0.108420  ...
# 1        1.040797     0.990089    0.971670    1.007045   -0.178911  ...
# 2        0.196087     0.990116    0.971643    1.012936   -0.192552  ...
# 3       -0.425374     0.996747    0.999958    1.012690   -0.110163  ...
# 4        3.825850     1.002818    0.983762    1.017019   -0.184912  ...
# ...           ...          ...         ...         ...         ...  ...
# 1915     0.285654    -1.884563   -1.896573   -1.864305   -0.205721  ...
# 1916     0.697457    -1.886426   -1.902904   -1.868388   -0.209985  ...
# 1917    -0.006788    -1.886017   -1.902116   -1.867210   -0.207095  ...
# 1918    -0.206645    -1.885925   -1.902687   -1.873403   -0.204972  ...
# 1919     1.145437    -1.886362   -1.903013   -1.866278   -0.209427  ...
#
#       T_ymag_var  T_ymag_std  T_ymag_skew  T_zmag_mean  T_zmag_max  \
# 0      -0.192554   -0.399481     0.874860     1.239708    1.253362
# 1      -0.209013   -0.592831     0.011989     1.242940    1.245143
# 2      -0.211727   -0.643184     0.397270     1.241130    1.228028
# 3      -0.194343   -0.416077    -1.366951     1.229393    1.213592
# 4      -0.209128   -0.594739    -0.239494     1.219803    1.222305
# ...          ...         ...          ...          ...         ...
# 1915    0.227029    1.031095    -2.584837     1.996404    2.010067
# 1916    0.260399    1.099830    -0.886403     1.996037    2.022864
# 1917    0.108272    0.762572     0.029414     2.001361    2.015607
# 1918    0.200647    0.974901    -0.768375     1.999853    1.997504
# 1919    0.215735    1.007250     1.092702     1.996673    2.009443
#
#       T_zmag_min  T_zmag_var  T_zmag_std  T_zmag_skew      label
# 0       1.215181    0.412682    1.558880     0.193145    sitting
# 1       1.253054    0.135847    0.924821     0.938626    sitting
# 2       1.254948   -0.038744    0.350527     0.046363    sitting
# 3       1.239638   -0.110690   -0.005850     0.700639    sitting
# 4       1.245319   -0.126857   -0.112895     3.285128    sitting
# ...          ...         ...         ...          ...        ...
# 1915    1.979892    0.002822    0.511246     0.252011  lyingRigh
# 1916    1.992560    0.000308    0.502110     0.982169  lyingRigh
# 1917    1.993494   -0.028101    0.393837     0.446742  lyingRigh
# 1918    1.979651   -0.027818    0.394966    -0.665737  lyingRigh
# 1919    1.987173    0.016626    0.560258     0.088148  lyingRigh
#
# [1920 rows x 55 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(scaled_X, 
                                                    scaled_X["label"],
                                                    test_size = 0.2, 
                                                    shuffle = True, 
                                                    random_state = 21)

# %%
print("X_train.shape: ", X_train.shape)
print("X_test.shape ", X_test.shape)
print("y_train.shape ", y_train.shape)
print("y_test.shape ", y_test.shape)
# Out:
# X_train.shape:  (1536, 55)
# X_test.shape  (384, 55)
# y_train.shape  (1536,)
# y_test.shape  (384,)

# %%
# The number of steps within one time segment
TIME_PERIODS = 80

# The steps to take from one segment to the next; if this value is equal to TIME_PERIODS, then there is
# no overlap between the segments
STEP_DISTANCE = 40

# %%
from scipy import stats
import numpy as np

def create_dataset(X, y, time_steps=1, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        v = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(v)        
        ys.append(stats.mode(labels)[0][0])
       
        # Retrieve the most often used label in this segment
        
    return np.array(Xs), np.array(ys).reshape(-1, 1)

TIME_STEPS = 5
STEP = 5

X_train, y_train = create_dataset(X_train[["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"]], X_train.label, TIME_STEPS, STEP)

X_test, y_test = create_dataset(X_test[["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"]], X_test.label, TIME_STEPS, STEP)

print(X_train.shape, y_train.shape)
# Out:
# (307, 5, 54) (307, 1)
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   ys.append(stats.mode(labels)[0][0])
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   ys.append(stats.mode(labels)[0][0])
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   ys.append(stats.mode(labels)[0][0])
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   ys.append(stats.mode(labels)[0][0])

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown = "ignore", sparse = False)
enc = enc.fit(y_train)

y_train = enc.transform(y_train)
y_test = enc.transform(y_test)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
print("X_train.shape: ", X_train.shape)
print("X_test.shape ", X_test.shape)
print("y_train.shape ", y_train.shape)
print("y_test.shape ", y_test.shape)
# Out:
# X_train.shape:  (307, 5, 54)
# X_test.shape  (76, 5, 54)
# y_train.shape  (307, 4)
# y_test.shape  (76, 4)

# %% [markdown]
# ### DL(CNN, LSTM)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

from tensorflow.keras.utils import to_categorical
import tensorflow.keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D
from keras.utils import np_utils

# %%
#Epoch 500

verbose, batch_size=1,32 

n_timesteps,n_features,n_outputs=X_train.shape[1],X_train.shape[2],y_train.shape[1]

# %%
n_timesteps,n_features,n_outputs
# Out:
# (5, 54, 4)

# %%
# Training and evaluating the LSTM model

model = keras.Sequential()
model.add(Bidirectional(LSTM(units = 128, input_shape = [X_train.shape[1], X_train.shape[2]])))
model.add(Dropout(rate = 0.5))
model.add(Dense(units = 128, activation = "relu"))
model.add(Dense(y_train.shape[1], activation = "softmax"))
model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["acc"])

# %%
history = model.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_split = 0.1, shuffle = True)
print(model.summary())
# Out:
# Epoch 1/100
# 9/9 [==============================] - 9s 186ms/step - loss: 1.2726 - acc: 0.4710 - val_loss: 1.1823 - val_acc: 0.4839
# Epoch 2/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.9607 - acc: 0.6884 - val_loss: 0.9907 - val_acc: 0.5161
# Epoch 3/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.7486 - acc: 0.7355 - val_loss: 0.8431 - val_acc: 0.5484
# Epoch 4/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6079 - acc: 0.7790 - val_loss: 0.7850 - val_acc: 0.6452
# Epoch 5/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5210 - acc: 0.7971 - val_loss: 0.7721 - val_acc: 0.5806
# Epoch 6/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4293 - acc: 0.8551 - val_loss: 0.7444 - val_acc: 0.6129
# Epoch 7/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3853 - acc: 0.8587 - val_loss: 0.7747 - val_acc: 0.6129
# Epoch 8/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3091 - acc: 0.8949 - val_loss: 0.7947 - val_acc: 0.6452
# Epoch 9/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.2672 - acc: 0.9022 - val_loss: 0.8287 - val_acc: 0.6452
# Epoch 10/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2210 - acc: 0.9312 - val_loss: 0.8642 - val_acc: 0.6452
# Epoch 11/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.1741 - acc: 0.9457 - val_loss: 0.9453 - val_acc: 0.6452
# Epoch 12/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1537 - acc: 0.9601 - val_loss: 0.9774 - val_acc: 0.6129
# Epoch 13/100
# 9/9 [==============================] - 0s 20ms/step - loss: 0.1473 - acc: 0.9384 - val_loss: 1.0893 - val_acc: 0.6129
# Epoch 14/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.1081 - acc: 0.9746 - val_loss: 1.0966 - val_acc: 0.6129
# Epoch 15/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0825 - acc: 0.9819 - val_loss: 1.2089 - val_acc: 0.6129
# Epoch 16/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0717 - acc: 0.9855 - val_loss: 1.1691 - val_acc: 0.6774
# Epoch 17/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0741 - acc: 0.9710 - val_loss: 1.2427 - val_acc: 0.5806
# Epoch 18/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0465 - acc: 0.9964 - val_loss: 1.4031 - val_acc: 0.5806
# Epoch 19/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0414 - acc: 0.9891 - val_loss: 1.3482 - val_acc: 0.5806
# Epoch 20/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0511 - acc: 0.9891 - val_loss: 1.3567 - val_acc: 0.6129
# Epoch 21/100
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0190 - acc: 1.0000 - val_loss: 1.5086 - val_acc: 0.5806
# Epoch 22/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0244 - acc: 1.0000 - val_loss: 1.5343 - val_acc: 0.5806
# Epoch 23/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0152 - acc: 1.0000 - val_loss: 1.4988 - val_acc: 0.5806
# Epoch 24/100
# 9/9 [==============================] - 0s 20ms/step - loss: 0.0139 - acc: 0.9964 - val_loss: 1.6809 - val_acc: 0.5806
# Epoch 25/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0079 - acc: 1.0000 - val_loss: 1.6528 - val_acc: 0.6129
# Epoch 26/100
# 9/9 [==============================] - 0s 21ms/step - loss: 0.0067 - acc: 1.0000 - val_loss: 1.6674 - val_acc: 0.6129
# Epoch 27/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0095 - acc: 0.9964 - val_loss: 1.8110 - val_acc: 0.5484
# Epoch 28/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0073 - acc: 1.0000 - val_loss:
# Epoch 88/100
# 9/9 [==============================] - 0s 25ms/step - loss: 4.3571e-04 - acc: 1.0000 - val_loss: 2.5046 - val_acc: 0.5806
# Epoch 89/100
# 9/9 [==============================] - 0s 22ms/step - loss: 3.3917e-04 - acc: 1.0000 - val_loss: 2.4975 - val_acc: 0.5806
# Epoch 90/100
# 9/9 [==============================] - 0s 20ms/step - loss: 4.8050e-04 - acc: 1.0000 - val_loss: 2.5107 - val_acc: 0.5806
# Epoch 91/100
# 9/9 [==============================] - 0s 21ms/step - loss: 5.6000e-04 - acc: 1.0000 - val_loss: 2.5174 - val_acc: 0.5806
# Epoch 92/100
# 9/9 [==============================] - 0s 24ms/step - loss: 3.2420e-04 - acc: 1.0000 - val_loss: 2.5242 - val_acc: 0.5806
# Epoch 93/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 2.3914 - val_acc: 0.5806
# Epoch 94/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 2.4440 - val_acc: 0.5806
# Epoch 95/100
# 9/9 [==============================] - 0s 21ms/step - loss: 1.8531e-04 - acc: 1.0000 - val_loss: 2.4980 - val_acc: 0.5806
# Epoch 96/100
# 9/9 [==============================] - 0s 23ms/step - loss: 3.2267e-04 - acc: 1.0000 - val_loss: 2.5110 - val_acc: 0.5806
# Epoch 97/100
# 9/9 [==============================] - 0s 18ms/step - loss: 3.6173e-04 - acc: 1.0000 - val_loss: 2.5143 - val_acc: 0.5806
# Epoch 98/100
# 9/9 [==============================] - 0s 21ms/step - loss: 1.8401e-04 - acc: 1.0000 - val_loss: 2.5164 - val_acc: 0.5806
# Epoch 99/100
# 9/9 [==============================] - 0s 25ms/step - loss: 2.1597e-04 - acc: 1.0000 - val_loss: 2.5370 - val_acc: 0.5806
# Epoch 100/100
# 9/9 [==============================] - 0s 21ms/step - loss: 1.9108e-04 - acc: 1.0000 - val_loss: 2.5556 - val_acc: 0.5806
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (None, 256)              187392
#  nal)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dense_10 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 220,804
# Trainable params: 220,804
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plt.plot(history.history["loss"], label = "train")
plt.plot(history.history["val_loss"], label = "test")
plt.legend()

# %%
model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 3/3 [==============================] - 0s 8ms/step - loss: 1.8105 - acc: 0.6711
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000281DBAB3520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 2s 5ms/step

# %%
from sklearn.metrics import confusion_matrix

def plot_cm(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(18, 16)) 
    ax = sns.heatmap(cm, annot = True, fmt = "d", cmap = sns.diverging_palette(220, 20, n = 7), ax = ax)

    plt.ylabel("Actual")
    plt.xlabel("Predicted")
    ax.set_xticklabels(class_names)
    ax.set_yticklabels(class_names)
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show()
    
plot_cm(enc.inverse_transform(y_test), enc.inverse_transform(y_pred), enc.categories_[0])

# %%
from sklearn.metrics import classification_report,confusion_matrix


y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# 3/3 [==============================] - 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        15
#            1       0.78      0.72      0.75        25
#            2       0.67      0.59      0.62        17
#            3       0.57      0.68      0.62        19
#
#     accuracy                           0.67        76
#    macro avg       0.67      0.66      0.67        76
# weighted avg       0.68      0.67      0.67        76
#
# [[10  1  1  3]
#  [ 2 18  3  2]
#  [ 1  1 10  5]
#  [ 2  3  1 13]]

# %%
#CNN MODEL (Default Setting)

inputs=keras.Input(shape=(n_timesteps,n_features))

conv_1=tf.keras.layers.Conv1D(filters=64,kernel_size=5,strides=2,activation='relu')(inputs)

avg_pooling=tf.keras.layers.GlobalAveragePooling1D()(conv_1)

batch_norm=tf.keras.layers.BatchNormalization()(avg_pooling)

output=tf.keras.layers.Dense(n_outputs,activation='softmax')(batch_norm)

cmodel=tf.keras.Model(inputs=inputs,outputs=output)
cmodel.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 5, 54)]           0
#
#  conv1d_3 (Conv1D)           (None, 1, 64)             17344
#
#  global_average_pooling1d_3   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_11 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 17,860
# Trainable params: 17,732
# Non-trainable params: 128
# _________________________________________________________________

# %%
cmodel.compile(loss='categorical_crossentropy',optimizer='RMSprop',metrics=['accuracy'])

history = cmodel.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_split = 0.1, shuffle = True)
print(cmodel.summary())
# Out:
# Epoch 1/100
# 9/9 [==============================] - 2s 47ms/step - loss: 1.5390 - accuracy: 0.3587 - val_loss: 1.1677 - val_accuracy: 0.4839
# Epoch 2/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.8118 - accuracy: 0.6957 - val_loss: 1.0448 - val_accuracy: 0.5161
# Epoch 3/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5829 - accuracy: 0.7971 - val_loss: 0.9877 - val_accuracy: 0.5161
# Epoch 4/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5005 - accuracy: 0.8478 - val_loss: 0.9665 - val_accuracy: 0.5161
# Epoch 5/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3550 - accuracy: 0.9058 - val_loss: 0.8815 - val_accuracy: 0.5806
# Epoch 6/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3047 - accuracy: 0.9420 - val_loss: 0.8804 - val_accuracy: 0.5484
# Epoch 7/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2526 - accuracy: 0.9565 - val_loss: 0.8334 - val_accuracy: 0.6129
# Epoch 8/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1828 - accuracy: 0.9928 - val_loss: 0.7745 - val_accuracy: 0.6452
# Epoch 9/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1691 - accuracy: 0.9783 - val_loss: 0.8151 - val_accuracy: 0.6129
# Epoch 10/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1411 - accuracy: 0.9928 - val_loss: 0.7740 - val_accuracy: 0.6774
# Epoch 11/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1411 - accuracy: 0.9891 - val_loss: 0.7228 - val_accuracy: 0.6774
# Epoch 12/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0959 - accuracy: 1.0000 - val_loss: 0.6967 - val_accuracy: 0.7097
# Epoch 13/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0833 - accuracy: 0.9928 - val_loss: 0.7000 - val_accuracy: 0.7097
# Epoch 14/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0586 - accuracy: 1.0000 - val_loss: 0.6849 - val_accuracy: 0.7419
# Epoch 15/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0569 - accuracy: 1.0000 - val_loss: 0.6421 - val_accuracy: 0.7742
# Epoch 16/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.7140 - val_accuracy: 0.7097
# Epoch 17/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.7338 - val_accuracy: 0.6774
# Epoch 18/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.6956 - val_accuracy: 0.6774
# Epoch 19/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.7079 - val_accuracy: 0.7097
# Epoch 20/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.6994 - val_accuracy: 0.7097
# Epoch 21/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.7429 - val_accuracy: 0.7097
# Epoch 22/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.7306 - val_accuracy: 0.7097
# Epoch 23/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0186 - accuracy: 0.9964 - val_loss: 0.7052 - val_accuracy: 0.7097
# Epoch 24/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.7593 - val_accuracy: 0.7419
# Epoch 25/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.7890 - val_accuracy: 0.7419
# Epoch 26/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0184 - accuracy: 0.9964 - val_loss: 0.8474 - val_accuracy: 0.7419
# Epoch 27/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.8834 - val_accuracy: 0.7419
# Epoch 28/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.9103 - val_accuracy: 0.7097
# Epoch 29/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.9295 - val_accuracy: 0.7097
# Epoch 30/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.9416 - val_accuracy: 0.7097
# Epoch 31/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.9631 - val_accuracy: 0.7097
# Epoch 32/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.9858 - val_accuracy: 0.7097
# Epoch 33/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.0046 - val_accuracy: 0.7097
# Epoch 34/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.0241 - val_accuracy: 0.7097
# Epoch 35/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.0001 - val_accuracy: 0.7097
# Epoch 36/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.0016 - val_accuracy: 0.7097
# Epoch 37/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0695 - val_accuracy: 0.7419
# Epoch 38/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0606 - val_accuracy: 0.7419
# Epoch 39/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0345 - val_accuracy: 0.7419
# Epoch 40/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.1923 - val_accuracy: 0.7419
# Epoch 41/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.1440 - val_accuracy: 0.7097
# Epoch 42/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.1433 - val_accuracy: 0.7097
# Epoch 43/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1235 - val_accuracy: 0.7742
# Epoch 44/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1783 - val_accuracy: 0.7097
# Epoch 45/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.1633 - val_accuracy: 0.7742
# Epoch 46/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.1587 - val_accuracy: 0.7742
# Epoch 47/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1869 - val_accuracy: 0.7419
# Epoch 48/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.3017 - val_accuracy: 0.7419
# Epoch 49/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.2062 - val_accuracy: 0.7419
# Epoch 50/100
# 9/9 [==============================] - 0s 10ms/step - loss: 8.2625e-04 - accuracy: 1.0000 - val_loss: 1.2594 - val_accuracy: 0.7419
# Epoch 51/100
# 9/9 [==============================] - 0s 14ms/step - loss: 8.4662e-04 - accuracy: 1.0000 - val_loss: 1.3272 - val_accuracy: 0.7419
# Epoch 52/100
# 9/9 [==============================] - 0s 11ms/step - loss: 6.9013e-04 - accuracy: 1.0000 - val_loss: 1.3443 - val_accuracy: 0.7419
# Epoch 53/100
# 9/9 [==============================] - 0s 15ms/step - loss: 6.4291e-04 - accuracy: 1.0000 - val_loss: 1.3546 - val_accuracy: 0.7419
# Epoch 54/100
# 9/9 [==============================] - 0s 10ms/step - loss: 9.8586e-04 - accuracy: 1.0000 - val_loss: 1.3770 - val_accuracy: 0.7419
# Epoch 55/100
# 9/9 [==============================] - 0s 8ms/step - loss: 8.4030e-04 - accuracy: 1.0000 - val_loss: 1.4219 - val_accuracy: 0.7419
# Epoch 56/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.4362 - val_accuracy: 0.7419
# Epoch 57/100
# 9/9 [==============================] - 0s 16ms/step - loss: 6.7330e-04 - accuracy: 1.0000 - val_loss: 1.4409 - val_accuracy: 0.7097
# Epoch 58/100
# 9/9 [==============================] - 0s 11ms/step - loss: 4.4927e-04 - accuracy: 1.0000 - val_loss: 1.3924 - val_accuracy: 0.7419
# Epoch 59/100
# 9/9 [==============================] - 0s 12ms/step - loss: 6.3356e-04 - accuracy: 1.0000 - val_loss: 1.3650 - val_accuracy: 0.7419
# Epoch 60/100
# 9/9 [==============================] - 0s 9ms/step - loss: 5.7991e-04 - accuracy: 1.0000 - val_loss: 1.4396 - val_accuracy: 0.7097
# Epoch 61/100
# 9/9 [==============================] - 0s 10ms/step - loss: 4.8935e-04 - accuracy: 1.0000 - val_loss: 1.4643 - val_accuracy: 0.7097
# Epoch 62/100
# 9/9 [==============================] - 0s 8ms/step - loss: 6.6229e-04 - accuracy: 1.0000 - val_loss: 1.3706 - val_accuracy: 0.7097
# Epoch 63/100
# 9/9 [==============================] - 0s 14ms/step - loss: 3.0187e-04 - accuracy: 1.0000 - val_loss: 1.3367 - val_accuracy: 0.7097
# Epoch 64/100
# 9/9 [==============================] - 0s 9ms/step - loss: 4.0802e-04 - accuracy: 1.0000 - val_loss: 1.2968 - val_accuracy: 0.7419
# Epoch 65/100
# 9/9 [==============================] - 0s 11ms/step - loss: 2.8844e-04 - accuracy: 1.0000 - val_loss: 1.3529 - val_accuracy: 0.7419
# Epoch 66/100
# 9/9 [==============================] - 0s 11ms/step - loss: 2.0354e-04 - accuracy: 1.0000 - val_loss: 1.3776 - val_accuracy: 0.7097
# Epoch 67/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2.4366e-04 - accuracy: 1.0000 - val_loss: 1.4204 - val_accuracy: 0.7097
# Epoch 68/100
# 9/9 [==============================] - 0s 9ms/step - loss: 
100
# 9/9 [==============================] - 0s 12ms/step - loss: 1.7049e-04 - accuracy: 1.0000 - val_loss: 1.4946 - val_accuracy: 0.7742
# Epoch 96/100
# 9/9 [==============================] - 0s 12ms/step - loss: 7.2040e-05 - accuracy: 1.0000 - val_loss: 1.4964 - val_accuracy: 0.7742
# Epoch 97/100
# 9/9 [==============================] - 0s 14ms/step - loss: 1.4406e-04 - accuracy: 1.0000 - val_loss: 1.5829 - val_accuracy: 0.7419
# Epoch 98/100
# 9/9 [==============================] - 0s 12ms/step - loss: 8.6108e-05 - accuracy: 1.0000 - val_loss: 1.5693 - val_accuracy: 0.7419
# Epoch 99/100
# 9/9 [==============================] - 0s 9ms/step - loss: 8.5611e-05 - accuracy: 1.0000 - val_loss: 1.5573 - val_accuracy: 0.7419
# Epoch 100/100
# 9/9 [==============================] - 0s 10ms/step - loss: 4.5410e-05 - accuracy: 1.0000 - val_loss: 1.5600 - val_accuracy: 0.7419
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 5, 54)]           0
#
#  conv1d_3 (Conv1D)           (None, 1, 64)             17344
#
#  global_average_pooling1d_3   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_11 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 17,860
# Trainable params: 17,732
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
from sklearn.metrics import classification_report,confusion_matrix


y_pred = cmodel.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# 3/3 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.58      0.73      0.65        15
#            1       0.94      0.68      0.79        25
#            2       0.53      0.59      0.56        17
#            3       0.50      0.53      0.51        19
#
#     accuracy                           0.63        76
#    macro avg       0.64      0.63      0.63        76
# weighted avg       0.67      0.63      0.64        76
#
# [[11  1  2  1]
#  [ 2 17  4  2]
#  [ 0  0 10  7]
#  [ 6  0  3 10]]

# %% [markdown]
# ### ML(SVM, DT, RF, LR)

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
enc = OneHotEncoder(handle_unknown="ignore", sparse=False)
enc = enc.fit(y_train)

y_train = enc.transform(y_train)
y_test = enc.transform(y_test)
                       
y_train = np.argmax(y_train, axis=1)
y_test = np.argmax(y_test, axis=1)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Classification

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
# SVM

clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)
pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("SVC Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_svm), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- SVM Classifier ---
# 0.9078947368421053
# [[61  0]
#  [ 7  8]]

# %%
# DT

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)
pred_dt = clf_dt.predict(X_test)

print("\n--- Decision Tree Classifier ---")
print(accuracy_score(y_test, pred_dt))
print(confusion_matrix(y_test, pred_dt))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Decision Tree Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_dt), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Decision Tree Classifier ---
# 0.8289473684210527
# [[54  7]
#  [ 6  9]]

# %%
# RF

rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred_rf = rf_clf.predict(X_test)

print("\n--- Random Forest ---")
print(accuracy_score(y_test,pred_rf))
print(confusion_matrix(y_test, pred_rf))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Random Forest Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_rf), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Random Forest ---
# 0.8552631578947368
# [[59  2]
#  [ 9  6]]

# %%
# LR

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, y_train)
pred_lr = clf_lr.predict(X_test)

print("\n--- Logistic Regression Classifier ---")
print(accuracy_score(y_test, pred_lr))
print(confusion_matrix(y_test, pred_lr))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Logistic Regression Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_lr), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Logistic Regression Classifier ---
# 0.868421052631579
# [[55  6]
#  [ 4 11]]

# %% [markdown]
# # Mild Accuracy
# ### ML (SVM: 90.7%, DT: 82.8%, RF: 85.5%, LR: 86.8%)
# ### DL (CNN: 61%, LSTM: 68%)

# %% [markdown]
# ## Medium

# %%
##x,y,z dont have the same variance so we need to scale the data 
#Standardized data:

from sklearn.preprocessing import StandardScaler

X = X_Medium[["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"]]

y = y_Medium
              
scaler = StandardScaler()
X = scaler.fit_transform(X)

scaled_X = pd.DataFrame(data = X, columns = ["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"])
scaled_X['label'] = y.values

scaled_X
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0       -1.962771    0.400142   -2.640259    2.735247    2.504592
# 1       -1.999061    0.651195   -2.640259    2.655881    2.451528
# 2       -1.961312    1.626387   -2.640259    3.128545    2.760088
# 3       -2.108777    0.299586   -2.640259    2.557202    2.384794
# 4       -1.889616    0.239522   -2.640259    2.696015    2.478428
# ...           ...         ...         ...         ...         ...
# 2395     0.861831    1.090537   -0.590518    0.982790    1.171356
# 2396     0.922040    0.771997   -0.684489    1.392966    1.520409
# 2397     1.088289    0.955563   -0.692389    1.429840    1.550417
# 2398     1.082795    0.900898   -0.582372    1.438561    1.557485
# 2399     0.971413    1.291650   -0.714324    1.542774    1.641065
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -2.330479     0.492545   -0.258262    0.847007   -0.507614  ...
# 1       -2.336072     0.654548    0.049546    1.157796   -0.027255  ...
# 2       -1.765458     0.959722    0.690153    0.711608   -0.260909  ...
# 3       -2.399773     0.927973    0.243535    0.934182   -0.568822  ...
# 4       -2.444731     0.800245    0.238751    0.061022   -0.032703  ...
# ...           ...          ...         ...         ...         ...  ...
# 2395    -0.864596     0.310075    0.988394   -0.757237    0.809660  ...
# 2396    -0.891505     0.190086    0.721248   -0.507805    0.862874  ...
# 2397    -1.009072     0.291545    0.602809   -0.478944    1.050534  ...
# 2398    -1.034897     0.191839    0.683720   -0.869933    1.254566  ...
# 2399    -0.944522     0.148526    0.862615   -0.780681    0.812454  ...
#
#       T_ymag_var  T_ymag_std  T_ymag_skew  T_zmag_mean  T_zmag_max  \
# 0       3.509592    3.244573    -2.498561    -0.081192    0.663069
# 1       2.567490    2.677614    -2.486160    -0.109516    0.663069
# 2       1.443887    1.872220    -2.659710    -0.092720    0.663069
# 3       1.149721    1.625158    -2.332033    -0.208492    0.663069
# 4       1.300602    1.754363    -2.444803    -0.125541    0.663069
# ...          ...         ...          ...          ...         ...
# 2395   -0.048978    0.258701     0.088012    -0.378907   -0.391657
# 2396   -0.010784    0.319939    -0.489234    -0.441505   -0.476319
# 2397    0.057636    0.424261     0.176306    -0.434321   -0.434984
# 2398    0.051372    0.414971    -0.453254    -0.429088   -0.458889
# 2399    0.016395    0.362157    -0.054934    -0.436833   -0.433549
#
#       T_zmag_min  T_zmag_var  T_zmag_std  T_zmag_skew                    label
# 0      -0.438534    4.118534    3.769177     2.090534          ascendingStairs
# 1      -0.328148    3.979926    3.693016     2.709631          ascendingStairs
# 2      -0.301339    3.800294    3.592520     2.781056          ascendingStairs
# 3      -0.540342    4.969328    4.213336     2.520547          ascendingStairs
# 4      -0.397070    4.143130    3.782571     2.658237          ascendingStairs
# ...          ...         ...         ...          ...                      ...
# 2395   -0.352613   -0.259372   -0.182068     0.285672  walkingTreadmillIncline
# 2396   -0.421072   -0.211489   -0.063496     0.245809  walkingTreadmillIncline
# 2397   -0.381274   -0.229992   -0.107820     0.414741  walkingTreadmillIncline
# 2398   -0.390776   -0.237488   -0.126283     0.168054  walkingTreadmillIncline
# 2399   -0.456335   -0.195629   -0.026814     0.091736  walkingTreadmillIncline
#
# [2400 rows x 55 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(scaled_X, 
                                                    scaled_X["label"],
                                                    test_size = 0.2, 
                                                    shuffle = True, 
                                                    random_state = 21)

# %%
print("X_train.shape: ", X_train.shape)
print("X_test.shape ", X_test.shape)
print("y_train.shape ", y_train.shape)
print("y_test.shape ", y_test.shape)
# Out:
# X_train.shape:  (1920, 55)
# X_test.shape  (480, 55)
# y_train.shape  (1920,)
# y_test.shape  (480,)

# %%
# The number of steps within one time segment
TIME_PERIODS = 80

# The steps to take from one segment to the next; if this value is equal to TIME_PERIODS, then there is
# no overlap between the segments
STEP_DISTANCE = 40

# %%
from scipy import stats
import numpy as np

def create_dataset(X, y, time_steps=1, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        v = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(v)        
        ys.append(stats.mode(labels)[0][0])
       
        # Retrieve the most often used label in this segment
        
    return np.array(Xs), np.array(ys).reshape(-1, 1)

TIME_STEPS = 5
STEP = 5

X_train, y_train = create_dataset(X_train[["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"]], X_train.label, TIME_STEPS, STEP)

X_test, y_test = create_dataset(X_test[["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"]], X_test.label, TIME_STEPS, STEP)

print(X_train.shape, y_train.shape)
# Out:
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   ys.append(stats.mode(labels)[0][0])
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   ys.append(stats.mode(labels)[0][0])
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   ys.append(stats.mode(labels)[0][0])
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   ys.append(stats.mode(labels)[0][0])
# (383, 5, 54) (383, 1)

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown = "ignore", sparse = False)
enc = enc.fit(y_train)

y_train = enc.transform(y_train)
y_test = enc.transform(y_test)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
print("X_train.shape: ", X_train.shape)
print("X_test.shape ", X_test.shape)
print("y_train.shape ", y_train.shape)
print("y_test.shape ", y_test.shape)
# Out:
# X_train.shape:  (383, 5, 54)
# X_test.shape  (95, 5, 54)
# y_train.shape  (383, 5)
# y_test.shape  (95, 5)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

from tensorflow.keras.utils import to_categorical
import tensorflow.keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D
from keras.utils import np_utils

# %%
#Epoch 500

verbose, batch_size=1,32 

n_timesteps,n_features,n_outputs=X_train.shape[1],X_train.shape[2],y_train.shape[1]

# %%
n_timesteps,n_features,n_outputs
# Out:
# (5, 54, 5)

# %%
# Training and evaluating the LSTM model

model = keras.Sequential()
model.add(Bidirectional(LSTM(units = 128, input_shape = [X_train.shape[1], X_train.shape[2]])))
model.add(Dropout(rate = 0.5))
model.add(Dense(units = 128, activation = "relu"))
model.add(Dense(y_train.shape[1], activation = "softmax"))
model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = 
100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0451 - acc: 0.9884 - val_loss: 2.2270 - val_acc: 0.6410
# Epoch 74/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0069 - acc: 1.0000 - val_loss: 1.6078 - val_acc: 0.6923
# Epoch 75/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0090 - acc: 0.9971 - val_loss: 1.5893 - val_acc: 0.6667
# Epoch 76/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0047 - acc: 1.0000 - val_loss: 1.9054 - val_acc: 0.6410
# Epoch 77/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0103 - acc: 0.9971 - val_loss: 1.6677 - val_acc: 0.6410
# Epoch 78/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0062 - acc: 0.9971 - val_loss: 1.6215 - val_acc: 0.6923
# Epoch 79/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.5089 - val_acc: 0.7179
# Epoch 80/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0024 - acc: 1.0000 - val_loss: 1.4412 - val_acc: 0.7179
# Epoch 81/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 1.4401 - val_acc: 0.7436
# Epoch 82/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 1.4549 - val_acc: 0.7179
# Epoch 83/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 1.4651 - val_acc: 0.7179
# Epoch 84/100
# 11/11 [==============================] - 0s 18ms/step - loss: 9.5657e-04 - acc: 1.0000 - val_loss: 1.4516 - val_acc: 0.7179
# Epoch 85/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.5247 - val_acc: 0.7436
# Epoch 86/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 1.6728 - val_acc: 0.7692
# Epoch 87/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 1.7102 - val_acc: 0.7436
# Epoch 88/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 1.6703 - val_acc: 0.7179
# Epoch 89/100
# 11/11 [==============================] - 0s 17ms/step - loss: 4.7587e-04 - acc: 1.0000 - val_loss: 1.6446 - val_acc: 0.7179
# Epoch 90/100
# 11/11 [==============================] - 0s 16ms/step - loss: 4.2672e-04 - acc: 1.0000 - val_loss: 1.6481 - val_acc: 0.7436
# Epoch 91/100
# 11/11 [==============================] - 0s 18ms/step - loss: 6.9194e-04 - acc: 1.0000 - val_loss: 1.6491 - val_acc: 0.7436
# Epoch 92/100
# 11/11 [==============================] - 0s 17ms/step - loss: 7.3459e-04 - acc: 1.0000 - val_loss: 1.6413 - val_acc: 0.7692
# Epoch 93/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 1.6719 - val_acc: 0.6923
# Epoch 94/100
# 11/11 [==============================] - 0s 19ms/step - loss: 7.9779e-04 - acc: 1.0000 - val_loss: 1.7510 - val_acc: 0.6667
# Epoch 95/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 1.7240 - val_acc: 0.6923
# Epoch 96/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 1.8302 - val_acc: 0.6410
# Epoch 97/100
# 11/11 [==============================] - 0s 20ms/step - loss: 3.3546e-04 - acc: 1.0000 - val_loss: 1.9467 - val_acc: 0.6410
# Epoch 98/100
# 11/11 [==============================] - 0s 17ms/step - loss: 3.2706e-04 - acc: 1.0000 - val_loss: 1.9717 - val_acc: 0.6410
# Epoch 99/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 2.0261 - val_acc: 0.6410
# Epoch 100/100
# 11/11 [==============================] - 0s 17ms/step - loss: 3.2664e-04 - acc: 1.0000 - val_loss: 2.0799 - val_acc: 0.6410
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (None, 256)              187392
#  nal)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 128)               32896
#
#  dense_13 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 220,933
# Trainable params: 220,933
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plt.plot(history.history["loss"], label = "train")
plt.plot(history.history["val_loss"], label = "test")
plt.legend()

# %%
model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3675 - acc: 0.6737
# 3/3 [==============================] - 1s 6ms/step

# %%
from sklearn.metrics import confusion_matrix

def plot_cm(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(18, 16)) 
    ax = sns.heatmap(cm, annot = True, fmt = "d", cmap = sns.diverging_palette(220, 20, n = 7), ax = ax)

    plt.ylabel("Actual")
    plt.xlabel("Predicted")
    ax.set_xticklabels(class_names)
    ax.set_yticklabels(class_names)
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show()
    
plot_cm(enc.inverse_transform(y_test), enc.inverse_transform(y_pred), enc.categories_[0])

# %%
from sklearn.metrics import classification_report,confusion_matrix


y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# 3/3 [==============================] - 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81        19
#            1       0.77      0.81      0.79        21
#            2       0.59      0.53      0.56        19
#            3       0.60      0.63      0.62        19
#            4       0.56      0.59      0.57        17
#
#     accuracy                           0.67        95
#    macro avg       0.67      0.67      0.67        95
# weighted avg       0.67      0.67      0.67        95
#
# [[15  1  1  0  2]
#  [ 1 17  0  1  2]
#  [ 0  2 10  3  4]
#  [ 1  2  4 12  0]
#  [ 1  0  2  4 10]]

# %%
#CNN MODEL (Default Setting)

inputs=keras.Input(shape=(n_timesteps,n_features))

conv_1=tf.keras.layers.Conv1D(filters=64,kernel_size=5,strides=2,activation='relu')(inputs)

avg_pooling=tf.keras.layers.GlobalAveragePooling1D()(conv_1)

batch_norm=tf.keras.layers.BatchNormalization()(avg_pooling)

output=tf.keras.layers.Dense(n_outputs,activation='softmax')(batch_norm)

cmodel=tf.keras.Model(inputs=inputs,outputs=output)
cmodel.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 5, 54)]           0
#
#  conv1d_4 (Conv1D)           (None, 1, 64)             17344
#
#  global_average_pooling1d_4   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_14 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 17,925
# Trainable params: 17,797
# Non-trainable params: 128
# _________________________________________________________________

# %%
cmodel.compile(loss='categorical_crossentropy',optimizer='RMSprop',metrics=['accuracy'])

history = cmodel.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_split = 0.1, shuffle = True)
print(cmodel.summary())
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 27ms/step - loss: 1.8208 - accuracy: 0.2994 - val_loss: 1.5911 - val_accuracy: 0.2564
# Epoch 2/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.0339 - accuracy: 0.5988 - val_loss: 1.4947 - val_accuracy: 0.3333
# Epoch 3/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.7546 - accuracy: 0.7703 - val_loss: 1.4314 - val_accuracy: 0.3590
# Epoch 4/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5981 - accuracy: 0.8401 - val_loss: 1.3808 - val_accuracy: 0.3846
# Epoch 5/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4832 - accuracy: 0.8924 - val_loss: 1.3412 - val_accuracy: 0.3846
# Epoch 6/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3868 - accuracy: 0.9215 - val_loss: 1.3093 - val_accuracy: 0.4359
# Epoch 7/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2952 - accuracy: 0.9680 - val_loss: 1.2861 - val_accuracy: 0.4359
# Epoch 8/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2394 - accuracy: 0.9767 - val_loss: 1.2877 - val_accuracy: 0.4615
# Epoch 9/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1994 - accuracy: 0.9826 - val_loss: 1.2499 - val_accuracy: 0.4615
# Epoch 10/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1636 - accuracy: 0.9913 - val_loss: 1.2834 - val_accuracy: 0.5128
# Epoch 11/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1199 - accuracy: 1.0000 - val_loss: 1.2425 - val_accuracy: 0.5128
# Epoch 12/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0979 - accuracy: 1.0000 - val_loss: 1.2738 - val_accuracy: 0.4872
# Epoch 13/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0761 - accuracy: 1.0000 - val_loss: 1.2752 - val_accuracy: 0.4872
# Epoch 14/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0686 - accuracy: 1.0000 - val_loss: 1.2905 - val_accuracy: 0.5128
# Epoch 15/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0570 - accuracy: 1.0000 - val_loss: 1.3093 - val_accuracy: 0.4872
# Epoch 16/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0440 - accuracy: 1.0000 - val_loss: 1.3296 - val_accuracy: 0.4872
# Epoch 17/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.3785 - val_accuracy: 0.4615
# Epoch 18/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 1.3430 - val_accuracy: 0.4359
# Epoch 19/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0324 - accuracy: 1.0000 - val_loss: 1.3885 - val_accuracy: 0.4359
# Epoch 20/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 1.3850 - val_accuracy: 0.4615
# Epoch 21/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1
# 11/11 [==============================] - 0s 8ms/step - loss: 8.4619e-05 - accuracy: 1.0000 - val_loss: 2.5544 - val_accuracy: 0.4359
# Epoch 83/100
# 11/11 [==============================] - 0s 9ms/step - loss: 1.3414e-04 - accuracy: 1.0000 - val_loss: 2.5538 - val_accuracy: 0.4359
# Epoch 84/100
# 11/11 [==============================] - 0s 8ms/step - loss: 7.2704e-05 - accuracy: 1.0000 - val_loss: 2.5335 - val_accuracy: 0.4359
# Epoch 85/100
# 11/11 [==============================] - 0s 7ms/step - loss: 8.5440e-05 - accuracy: 1.0000 - val_loss: 2.5413 - val_accuracy: 0.4359
# Epoch 86/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1.1555e-04 - accuracy: 1.0000 - val_loss: 2.5501 - val_accuracy: 0.4103
# Epoch 87/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1.5493e-04 - accuracy: 1.0000 - val_loss: 2.5563 - val_accuracy: 0.4359
# Epoch 88/100
# 11/11 [==============================] - 0s 8ms/step - loss: 9.4070e-04 - accuracy: 1.0000 - val_loss: 2.6868 - val_accuracy: 0.4359
# Epoch 89/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.5973e-04 - accuracy: 1.0000 - val_loss: 2.6996 - val_accuracy: 0.4103
# Epoch 90/100
# 11/11 [==============================] - 0s 7ms/step - loss: 1.7553e-04 - accuracy: 1.0000 - val_loss: 2.6774 - val_accuracy: 0.4103
# Epoch 91/100
# 11/11 [==============================] - 0s 6ms/step - loss: 8.1478e-05 - accuracy: 1.0000 - val_loss: 2.6711 - val_accuracy: 0.4359
# Epoch 92/100
# 11/11 [==============================] - 0s 6ms/step - loss: 1.6588e-04 - accuracy: 1.0000 - val_loss: 2.6451 - val_accuracy: 0.4359
# Epoch 93/100
# 11/11 [==============================] - 0s 6ms/step - loss: 8.2061e-05 - accuracy: 1.0000 - val_loss: 2.6488 - val_accuracy: 0.4615
# Epoch 94/100
# 11/11 [==============================] - 0s 6ms/step - loss: 7.4598e-05 - accuracy: 1.0000 - val_loss: 2.6529 - val_accuracy: 0.4359
# Epoch 95/100
# 11/11 [==============================] - 0s 8ms/step - loss: 7.7881e-05 - accuracy: 1.0000 - val_loss: 2.6484 - val_accuracy: 0.4615
# Epoch 96/100
# 11/11 [==============================] - 0s 7ms/step - loss: 6.4398e-05 - accuracy: 1.0000 - val_loss: 2.6543 - val_accuracy: 0.4615
# Epoch 97/100
# 11/11 [==============================] - 0s 7ms/step - loss: 5.1195e-05 - accuracy: 1.0000 - val_loss: 2.6437 - val_accuracy: 0.4615
# Epoch 98/100
# 11/11 [==============================] - 0s 8ms/step - loss: 1.2863e-04 - accuracy: 1.0000 - val_loss: 2.5821 - val_accuracy: 0.4103
# Epoch 99/100
# 11/11 [==============================] - 0s 10ms/step - loss: 5.7593e-05 - accuracy: 1.0000 - val_loss: 2.5876 - val_accuracy: 0.4359
# Epoch 100/100
# 11/11 [==============================] - 0s 9ms/step - loss: 6.8903e-05 - accuracy: 1.0000 - val_loss: 2.5750 - val_accuracy: 0.4103
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 5, 54)]           0
#
#  conv1d_4 (Conv1D)           (None, 1, 64)             17344
#
#  global_average_pooling1d_4   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_14 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 17,925
# Trainable params: 17,797
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
from sklearn.metrics import classification_report,confusion_matrix


y_pred = cmodel.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# 3/3 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.52      0.63      0.57        19
#            1       0.78      0.67      0.72        21
#            2       0.29      0.26      0.28        19
#            3       0.45      0.47      0.46        19
#            4       0.35      0.35      0.35        17
#
#     accuracy                           0.48        95
#    macro avg       0.48      0.48      0.48        95
# weighted avg       0.49      0.48      0.48        95
#
# [[12  0  4  2  1]
#  [ 0 14  3  1  3]
#  [ 6  2  5  2  4]
#  [ 2  1  4  9  3]
#  [ 3  1  1  6  6]]

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
enc = OneHotEncoder(handle_unknown="ignore", sparse=False)
enc = enc.fit(y_train)

y_train = enc.transform(y_train)
y_test = enc.transform(y_test)
                       
y_train = np.argmax(y_train, axis=1)
y_test = np.argmax(y_test, axis=1)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ### ML(SVM, DT, RF, LR)

# %%
# Classification

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
# SVM

clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)
pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("SVC Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_svm), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- SVM Classifier ---
# 0.8210526315789474
# [[76  0]
#  [17  2]]

# %%
# DT

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)
pred_dt = clf_dt.predict(X_test)

print("\n--- Decision Tree Classifier ---")
print(accuracy_score(y_test, pred_dt))
print(confusion_matrix(y_test, pred_dt))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Decision Tree Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_dt), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Decision Tree Classifier ---
# 0.7789473684210526
# [[69  7]
#  [14  5]]

# %%
# RF

rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred_rf = rf_clf.predict(X_test)

print("\n--- Random Forest ---")
print(accuracy_score(y_test,pred_rf))
print(confusion_matrix(y_test, pred_rf))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Random Forest Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_rf), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Random Forest ---
# 0.8315789473684211
# [[75  1]
#  [15  4]]

# %%
# LR

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, y_train)
pred_lr = clf_lr.predict(X_test)

print("\n--- Logistic Regression Classifier ---")
print(accuracy_score(y_test, pred_lr))
print(confusion_matrix(y_test, pred_lr))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Logistic Regression Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_lr), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Logistic Regression Classifier ---
# 0.8842105263157894
# [[70  6]
#  [ 5 14]]

# %% [markdown]
# # Medium Accuracy
# ### ML (SVM: 82.1%, DT: 77.8%, RF: 83.1%, LR: 88.4%)
# ### DL (CNN: 59%, LSTM: 67.3%)

# %% [markdown]
# ## Strong

# %%
##x,y,z dont have the same variance so we need to scale the data 
#Standardized data:

from sklearn.preprocessing import StandardScaler

X = X_Strong[["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"]]

y = y_Strong
              
scaler = StandardScaler()
X = scaler.fit_transform(X)

scaled_X = pd.DataFrame(data = X, columns = ["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"])
scaled_X['label'] = y.values

scaled_X
# Out:
#      T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0      -0.644594   -1.561758    1.322964   -1.443612   -1.782377    -1.178991
# 1       0.421954    0.598170    1.051746   -1.013493   -1.089338     0.584214
# 2      -0.278651   -0.961296    1.455131   -1.259207   -1.463196    -0.385126
# 3      -0.311672   -1.208284    1.751197   -1.293919   -1.520305    -0.352407
# 4       0.707175    0.944226    0.976988   -0.976088   -1.036372     1.210283
# ..           ...         ...         ...         ...         ...          ...
# 955    -0.085863   -0.746787   -0.096686    0.033955    0.153630    -0.719165
# 956    -1.156942   -0.606555   -0.319979    0.200385    0.319350    -0.264182
# 957     0.117593   -0.532458    0.139642   -0.036632    0.081381    -0.742598
# 958    -0.390225   -0.746063   -0.352108    0.052470    0.172381    -0.674554
# 959    -0.908692   -0.890728   -0.298696   -0.058618    0.058623    -0.683789
#
#      T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  T_ymag_var  \
# 0       1.358094   -0.289981    1.021002   -0.852647  ...   -0.078881
# 1       1.191610    0.140345    0.002808   -0.119639  ...    0.951652
# 2       1.045255   -0.012072   -0.020618   -0.423809  ...   -0.286872
# 3       1.262855    1.257790    0.201660   -0.082023  ...   -0.297878
# 4       0.853184   -0.080558    0.010053   -0.249087  ...    1.051728
# ..           ...         ...         ...         ...  ...         ...
# 955    -1.956038   -0.902063   -0.551241    0.034410  ...   -0.824990
# 956    -1.779211   -0.995493   -0.171902    0.038065  ...   -0.848813
# 957    -1.770241   -1.060450    0.333225   -0.320551  ...   -0.844960
# 958    -1.720181   -0.972532    0.076983   -0.199777  ...   -0.850870
# 959    -1.502502   -1.040168    0.275101   -0.405150  ...   -0.842884
#
#      T_ymag_std  T_ymag_skew  T_zmag_mean  T_zmag_max  T_zmag_min  T_zmag_var  \
# 0      0.227909    -0.133021    -1.160274   -1.145499   -1.191167   -0.164311
# 1      1.099528    -0.974564    -1.152190   -1.094169   -1.340559    0.309129
# 2     -0.010289     0.965336    -1.229211   -1.117076   -1.300592   -0.062900
# 3     -0.023994    -0.125103    -1.161993   -1.061938   -1.235555   -0.057808
# 4      1.168813    -0.411101    -1.139257   -1.022594   -1.399631    0.408520
# ..          ...          ...          ...         ...         ...         ...
# 955   -1.051488     1.453946     0.149710    0.036084    0.290182   -0.615331
# 956   -1.175372    -0.049162     0.146297   -0.015189    0.339747   -0.655270
# 957   -1.151923     0.018912     0.223804    0.087553    0.459648   -0.667865
# 958   -1.188726     0.689203     0.207345    0.169546    0.340110   -0.509036
# 959   -1.140009     0.713196     0.219590    0.072936    0.423042   -0.649344
#
#      T_zmag_std  T_zmag_skew             label
# 0      0.067986    -0.618144  runningTreadmill
# 1      0.606843    -1.001032  runningTreadmill
# 2      0.196311    -0.134958  runningTreadmill
# 3      0.202527    -0.076787  runningTreadmill
# 4      0.704707    -0.975689  runningTreadmill
# ..          ...          ...               ...
# 955   -0.682147     0.130643           jumping
# 956   -0.777384     0.628871           jumping
# 957   -0.809520     1.082810           jumping
# 958   -0.463805     0.452607           jumping
# 959   -0.762644     0.487513           jumping
#
# [960 rows x 55 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(scaled_X, 
                                                    scaled_X["label"],
                                                    test_size = 0.2, 
                                                    shuffle = True, 
                                                    random_state = 21)

# %%
print("X_train.shape: ", X_train.shape)
print("X_test.shape ", X_test.shape)
print("y_train.shape ", y_train.shape)
print("y_test.shape ", y_test.shape)
# Out:
# X_train.shape:  (768, 55)
# X_test.shape  (192, 55)
# y_train.shape  (768,)
# y_test.shape  (192,)

# %%
# The number of steps within one time segment
TIME_PERIODS = 80

# The steps to take from one segment to the next; if this value is equal to TIME_PERIODS, then there is
# no overlap between the segments
STEP_DISTANCE = 40

# %%
from scipy import stats
import numpy as np

def create_dataset(X, y, time_steps=1, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        v = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(v)        
        ys.append(stats.mode(labels)[0][0])
       
        # Retrieve the most often used label in this segment
        
    return np.array(Xs), np.array(ys).reshape(-1, 1)

TIME_STEPS = 5
STEP = 5

X_train, y_train = create_dataset(X_train[["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"]], X_train.label, TIME_STEPS, STEP)

X_test, y_test = create_dataset(X_test[["T_xacc_mean", "T_xacc_max", "T_xacc_min","T_xacc_var", \
       "T_xacc_std", "T_xacc_skew", "T_yacc_mean", "T_yacc_max", "T_yacc_min", \
       "T_yacc_var", "T_yacc_std", "T_yacc_skew", "T_zacc_mean", "T_zacc_max", \
       "T_zacc_min", "T_zacc_var", "T_zacc_std", "T_zacc_skew", "T_xgyro_mean", \
       "T_xgyro_max", "T_xgyro_min", "T_xgyro_var", "T_xgyro_std", \
       "T_xgyro_skew", "T_ygyro_mean", "T_ygyro_max", "T_ygyro_min", \
       "T_ygyro_var", "T_ygyro_std", "T_ygyro_skew", "T_zgyro_mean", \
       "T_zgyro_max", "T_zgyro_min", "T_zgyro_var", "T_zgyro_std", \
       "T_zgyro_skew", "T_xmag_mean", "T_xmag_max", "T_xmag_min", "T_xmag_var",  \
       "T_xmag_std", "T_xmag_skew", "T_ymag_mean", "T_ymag_max", "T_ymag_min", \
       "T_ymag_var", "T_ymag_std", "T_ymag_skew", "T_zmag_mean", "T_zmag_max", \
       "T_zmag_min", "T_zmag_var", "T_zmag_std", "T_zmag_skew"]], X_test.label, TIME_STEPS, STEP)

print(X_train.shape, y_train.shape)
# Out:
# (153, 5, 54) (153, 1)
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   ys.append(stats.mode(labels)[0][0])
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   ys.append(stats.mode(labels)[0][0])
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   ys.append(stats.mode(labels)[0][0])
# C:\Users\jycha\AppData\Local\Temp\ipykernel_20340\2773420738.py:10: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   ys.append(stats.mode(labels)[0][0])

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown = "ignore", sparse = False)
enc = enc.fit(y_train)

y_train = enc.transform(y_train)
y_test = enc.transform(y_test)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
print("X_train.shape: ", X_train.shape)
print("X_test.shape ", X_test.shape)
print("y_train.shape ", y_train.shape)
print("y_test.shape ", y_test.shape)
# Out:
# X_train.shape:  (153, 5, 54)
# X_test.shape  (38, 5, 54)
# y_train.shape  (153, 2)
# y_test.shape  (38, 2)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

from tensorflow.keras.utils import to_categorical
import tensorflow.keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D
from keras.utils import np_utils

# %%
#Epoch 500

verbose, batch_size=1,32 

n_timesteps,n_features,n_outputs=X_train.shape[1],X_train.shape[2],y_train.shape[1]

# %%
n_timesteps,n_features,n_outputs
# Out:
# (5, 54, 2)

# %%
# Training and evaluating the LSTM model

model = keras.Sequential()
model.add(Bidirectional(LSTM(units = 128, input_shape = [X_train.shape[1], X_train.shape[2]])))
model.add(Dropout(rate = 0.5))
model.add(Dense(units = 128, activation = "relu"))
model.add(Dense(y_train.shape[1], activation = "softmax"))
model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["acc"])

# %%
history = model.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_split = 0.1, shuffle = True)
print(model.summary())
# Out:
# Epoch 1/100
# 5/5 [==============================] - 6s 240ms/step - loss: 0.6595 - acc: 0.6058 - val_loss: 0.5203 - val_acc: 0.7500
# Epoch 2/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4704 - acc: 0.8467 - val_loss: 0.4119 - val_acc: 0.7500
# Epoch 3/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3544 - acc: 0.8613 - val_loss: 0.3397 - val_acc: 0.8125
# Epoch 4/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2411 - acc: 0.9270 - val_loss: 0.2652 - val_acc: 0.8125
# Epoch 5/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1630 - acc: 0.9635 - val_loss: 0.1813 - val_acc: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1048 - acc: 0.9854 - val_loss: 0.1098 - val_acc: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0576 - acc: 0.9927 - val_loss: 0.0576 - val_acc: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0478 - acc: 0.9927 - val_loss: 0.0334 - val_acc: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.

#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_15 (Dense)            (None, 128)               32896
#
#  dense_16 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 220,546
# Trainable params: 220,546
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plt.plot(history.history["loss"], label = "train")
plt.plot(history.history["val_loss"], label = "test")
plt.legend()

# %%
model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0576 - acc: 0.9737
# 2/2 [==============================] - 1s 5ms/step

# %%
from sklearn.metrics import confusion_matrix

def plot_cm(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(18, 16)) 
    ax = sns.heatmap(cm, annot = True, fmt = "d", cmap = sns.diverging_palette(220, 20, n = 7), ax = ax)

    plt.ylabel("Actual")
    plt.xlabel("Predicted")
    ax.set_xticklabels(class_names)
    ax.set_yticklabels(class_names)
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show()
    
plot_cm(enc.inverse_transform(y_test), enc.inverse_transform(y_pred), enc.categories_[0])

# %%
from sklearn.metrics import classification_report,confusion_matrix


y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# 2/2 [==============================] - 0s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        18
#            1       1.00      0.95      0.97        20
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38
#
# [[18  0]
#  [ 1 19]]

# %%
#CNN MODEL (Default Setting)

inputs=keras.Input(shape=(n_timesteps,n_features))

conv_1=tf.keras.layers.Conv1D(filters=64,kernel_size=5,strides=2,activation='relu')(inputs)

avg_pooling=tf.keras.layers.GlobalAveragePooling1D()(conv_1)

batch_norm=tf.keras.layers.BatchNormalization()(avg_pooling)

output=tf.keras.layers.Dense(n_outputs,activation='softmax')(batch_norm)

cmodel=tf.keras.Model(inputs=inputs,outputs=output)
cmodel.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 5, 54)]           0
#
#  conv1d_5 (Conv1D)           (None, 1, 64)             17344
#
#  global_average_pooling1d_5   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_17 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 17,730
# Trainable params: 17,602
# Non-trainable params: 128
# _________________________________________________________________

# %%
cmodel.compile(loss='categorical_crossentropy',optimizer='RMSprop',metrics=['accuracy'])

history = cmodel.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_split = 0.1, shuffle = True)
print(cmodel.summary())
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 56ms/step - loss: 0.7551 - accuracy: 0.5693 - val_loss: 0.4727 - val_accuracy: 0.7500
# Epoch 2/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3286 - accuracy: 0.8540 - val_loss: 0.4534 - val_accuracy: 0.8125
# Epoch 3/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1968 - accuracy: 0.9416 - val_loss: 0.4318 - val_accuracy: 0.8125
# Epoch 4/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1503 - accuracy: 0.9781 - val_loss: 0.4058 - val_accuracy: 0.8750
# Epoch 5/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1160 - accuracy: 0.9927 - val_loss: 0.3679 - val_accuracy: 0.8750
# Epoch 6/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0886 - accuracy: 0.9927 - val_loss: 0.3633 - val_accuracy: 0.8750
# Epoch 7/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0714 - accuracy: 1.0000 - val_loss: 0.3770 - val_accuracy: 0.8750
# Epoch 8/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0602 - accuracy: 1.0000 - val_loss: 0.3751 - val_accuracy: 0.8750
# Epoch 9/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.3605 - val_accuracy: 0.8750
# Epoch 10/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.3556 - val_accuracy: 0.8750
# Epoch 11/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0341 - accuracy: 1.0000 - val_loss: 0.3239 - val_accuracy: 0.8750
# Epoch 12/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.3420 - val_accuracy: 0.8750
# Epoch 13/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.3466 - val_accuracy: 0.8750
# Epoch 14/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.3512 - val_accuracy: 0.8750
# Epoch 15/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.3514 - val_accuracy: 0.8750
# Epoch 16/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.3393 - val_accuracy: 0.8750
# Epoch 17/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.8750
# Epoch 18/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.8125
# Epoch 19/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.3416 - val_accuracy: 0.8750
# Epoch 20/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.3230 - val_accuracy: 0.8750
# Epoch 21/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.3433 - val_accuracy: 0.8750
# Epoch 22/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.3403 - val_accuracy: 0.8750
# Epoch 23/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2947 - val_accuracy: 0.8750
# Epoch 24/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2920 - val_accuracy: 0.8750
# Epoch 25/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.3163 - val_accuracy: 0.8750
# Epoch 26/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.3273 - val_accuracy: 0.8750
# Epoch 27/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3505 - val_accuracy: 0.8750
# Epoch 28/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3595 - val_accuracy: 0.8750
# Epoch 29/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3621 - val_accuracy: 0.8125
# Epoch 30/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3647 - val_accuracy: 0.8125
# Epoch 31/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3688 - val_accuracy: 0.8750
# Epoch 32/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2975 - val_accuracy: 0.8750
# Epoch 33/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3149 - val_accuracy: 0.8750
# Epoch 34/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3105 - val_accuracy: 0.8750
# Epoch 35/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3161 - val_accuracy: 0.8750
# Epoch 36/100
# 5/5 [==============================] - 0s 11ms/step - loss: 9.4267e-04 - accuracy: 1.0000 - val_loss: 0.3271 - val_accuracy: 0.8750
# Epoch 37/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3598 - val_accuracy: 0.8750
# Epoch 38/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.4392 - val_accuracy: 0.8125
# Epoch 39/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4319 - val_accuracy: 0.8125
# Epoch 40/100
# 5/5 [==============================] - 0s 28ms/step - loss: 5.9313e-04 - accuracy: 1.0000 - val_loss: 0.4252 - val_accuracy: 0.8125
# Epoch 41/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0143 - accuracy: 0.9927 - val_loss: 0.3752 - val_accuracy: 0.8125
# Epoch 42/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3827 - val_accuracy: 0.8125
# Epoch 43/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3873 - val_accuracy: 0.8125
# Epoch 44/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0088 - accuracy: 0.9927 - val_loss: 0.4227 - val_accuracy: 0.8750
# Epoch 45/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4371 - val_accuracy: 0.8750
# Epoch 46/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4328 - val_accuracy: 0.8125
# Epoch 47/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4410 - val_accuracy: 0.8125
# Epoch 48/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4995 - val_accuracy: 0.8750
# Epoch 49/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4778 - val_accuracy: 0.8750
# Epoch 50/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4655 - val_accuracy: 0.8750
# Epoch 51/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4717 - val_accuracy: 0.8125
# Epoch 52/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4370 - val_accuracy: 0.8125
# Epoch 53/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5552 - val_accuracy: 0.8125
# Epoch 54/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4941 - val_accuracy: 0.8125
# Epoch 55/100
# 5/5 [==============================] - 0s 14ms/step - loss: 6.7902e-04 - accuracy: 1.0000 - val_loss: 0.5235 - val_accuracy: 0.8125
# Epoch 56/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5235 - val_accuracy: 0.8125
# Epoch 57/100
# 5/5 [==============================] - 0s 11ms/step - loss: 4.6342e-04 - accuracy: 1.0000 - val_loss: 0.5270 - val_accuracy: 0.8125
# Epoch 58/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4988 - val_accuracy: 0.8125
# Epoch 59/100
# 5/5 [==============================] - 0s 12ms/step - loss: 8.0957e-04 - accuracy: 1.0000 - val_loss: 0.5195 - val_accuracy: 0.8125
# Epoch 60/100
# 5/5 [==============================] - 0s 12ms/step - loss: 4.9381e-04 - accuracy: 1.0000 - val_loss: 0.5532 - val_accuracy: 0.8125
# Epoch 61/100
# 5/5 [==============================] - 0s 13ms/step - loss: 4.6918e-04 - accuracy: 1.0000 - val_loss: 0.5474 - val_accuracy: 0.8125
# Epoch 62/100
# 5/5 [==============================] - 0s 18ms/step - loss: 9.4209e-04 - accuracy: 1.0000 - val_loss: 0.5470 - val_accuracy: 0.8125
# Epoch 63/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.5537 - val_accuracy: 0.7500
# Epoch 64/100
# 5/5 [==============================] - 0s 17ms/step - loss: 3.9353e-04 - accuracy: 1.0000 - val_loss: 0.5357 - val_accuracy: 0.7500
# Epoch 65/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5142 - val_accuracy: 0.8125
# Epoch 66/100
# 5/5 [==============================] - 0s 11ms/step - loss: 3.8601e-04 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.8125
# Epoch 67/100
# 5/5 [==============================] - 0s 11ms/step - loss: 4.6911e-04 - accuracy: 1.0000 - val_loss: 0.4925 - val_accuracy: 0.8125
# Epoch 68/100
# 5/5 [==============================] - 0s 12ms/step - loss: 9.2977e-04 - accuracy: 1.0000 - val_loss: 0.5026 - val_accuracy: 0.8125
# Epoch 69/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.9243e-04 - accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.8125
# Epoch 70/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.1069e-04 - accuracy: 1.0000 - val_loss: 0.5227 - val_accuracy: 0.8125
# Epoch 71/100
# 5/5 [==============================] - 0s 14ms/step - loss: 3.1967e-04 - accuracy: 1.0000 - val_loss: 0.5182 - val_accuracy: 0.8125
# Epoch 72/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.9415e-04 - accuracy: 1.0000 - val_loss: 0.5215 - val_accuracy: 0.8125
# Epoch 73/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5663 - val_accuracy: 0.8125
# Epoch 74/100
# 5/5 [==============================] - 0s 14ms/step - loss: 6.7884e-04 - accuracy: 1.0000 - val_loss: 0.5623 - val_accuracy: 0.8125
# Epoch 75/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.1848e-04 - accuracy: 1.0000 - val_loss: 0.5841 - val_accuracy: 0.8125
# Epoch 76/100
# 5/5 [==============================] - 0s 11ms/step - loss: 5.3899e-04 - accuracy: 1.0000 - val_loss: 0.5598 - val_accuracy: 0.8125
# Epoch 77/100
# 5/5 [==============================] - 0s 11ms/step - loss: 6.8912e-04 - accuracy: 1.0000 - val_loss: 0.5899 - val_accuracy: 0.8125
# Epoch 78/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.0031e-04 - accuracy: 1.0000 - val_loss: 0.5885 - val_accuracy: 0.8125
# Epoch 79/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.3849e-04 - accuracy: 1.0000 - val_loss: 0.5938 - val_accuracy: 0.8125
# Epoch 80/100
# 5/5 [==============================] - 0s 12ms/step - loss: 1.6204e-04 - accuracy: 1.0000 - val_loss: 0.5999 - val_accuracy: 0.8125
# Epoch 81/100
# 5/5 [==============================] - 0s 12ms/step - loss: 3.2264e-04 - accuracy: 1.0000 - val_loss: 0.5823 - val_accuracy: 0.8125
# Epoch 82/100
# 5/5 [==============================] - 0s 11ms/step - loss: 5.6957e-04 - accuracy: 1.0000 - val_loss: 0.6712 - val_accuracy: 0.7500
# Epoch 83/100
# 5/5 [==============================] - 0s 14ms/step - loss: 8.2583e-04 - accuracy: 1.0000 - val_loss: 0.7181 - val_accuracy: 0.7500
# Epoch 84/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6093 - val_accuracy: 0.7500
# Epoch 85/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6850 - val_accuracy: 0.8125
# Epoch 86/100
# 5/5 [==============================] - 0s 14ms/step - loss: 8.5962e-04 - accuracy: 1.0000 - val_loss: 0.6866 - val_accuracy: 0.7500
# Epoch 87/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.1303e-04 - accuracy: 1.0000 - val_loss: 0.6834 - val_accuracy: 0.7500
# Epoch 88/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.0357e-04 - accuracy: 1.0000 - val_loss: 0.6748 - val_accuracy: 0.8125
# Epoch 89/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.8985e-04 - accuracy: 1.0000 - val_loss: 0.6673 - val_accuracy: 0.8125
# Epoch 90/100
# 5/5 [==============================] - 0s 13ms/step - loss: 3.9730e-04 - accuracy: 1.0000 - val_loss: 0.6433 - val_accuracy: 0.8125
# Epoch 91/100
# 5/5 [==============================] - 0s 12ms/step - loss: 4.7016e-04 - accuracy: 1.0000 - val_loss: 0.7700 - val_accuracy: 0.7500
# Epoch 92/100
# 5/5 [==============================] - 0s 11ms/step - loss: 9.5936e-05 - accuracy: 1.0000 - val_loss: 0.7688 - val_accuracy: 0.7500
# Epoch 93/100
# 5/5 [==============================] - 0s 15ms/step - loss: 1.4027e-04 - accuracy: 1.0000 - val_loss: 0.7751 - val_accuracy: 0.7500
# Epoch 94/100
# 5/5 [==============================] - 0s 17ms/step - loss: 1.3242e-04 - accuracy: 1.0000 - val_loss: 0.7818 - val_accuracy: 0.7500
# Epoch 95/100
# 5/5 [==============================] - 0s 17ms/step - loss: 7.3512e-05 - accuracy: 1.0000 - val_loss: 0.7811 - val_accuracy: 0.7500
# Epoch 96/100
# 5/5 [==============================] - 0s 12ms/step - loss: 8.0497e-05 - accuracy: 1.0000 - val_loss: 0.7909 - val_accuracy: 0.7500
# Epoch 97/100
# 5/5 [==============================] - 0s 13ms/step - loss: 8.3288e-05 - accuracy: 1.0000 - val_loss: 0.7925 - val_accuracy: 0.7500
# Epoch 98/100
# 5/5 [==============================] - 0s 11ms/step - loss: 4.5689e-05 - accuracy: 1.0000 - val_loss: 0.7932 - val_accuracy: 0.7500
# Epoch 99/100
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0586e-04 - accuracy: 1.0000 - val_loss: 0.8043 - val_accuracy: 0.7500
# Epoch 100/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.1873e-04 - accuracy: 1.0000 - val_loss: 0.7998 - val_accuracy: 0.8125
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 5, 54)]           0
#
#  conv1d_5 (Conv1D)           (None, 1, 64)             17344
#
#  global_average_pooling1d_5   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_17 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 17,730
# Trainable params: 17,602
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
from sklearn.metrics import classification_report,confusion_matrix


y_pred = cmodel.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# 2/2 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86        18
#            1       0.89      0.85      0.87        20
#
#     accuracy                           0.87        38
#    macro avg       0.87      0.87      0.87        38
# weighted avg       0.87      0.87      0.87        38
#
# [[16  2]
#  [ 3 17]]

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
enc = OneHotEncoder(handle_unknown="ignore", sparse=False)
enc = enc.fit(y_train)

y_train = enc.transform(y_train)
y_test = enc.transform(y_test)
                       
y_train = np.argmax(y_train, axis=1)
y_test = np.argmax(y_test, axis=1)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ### ML(SVM, DT, RF, LR)

# %%
# Classification

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
# SVM

clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)
pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("SVC Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_svm), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- SVM Classifier ---
# 0.8947368421052632
# [[17  3]
#  [ 1 17]]

# %%
# DT

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)
pred_dt = clf_dt.predict(X_test)

print("\n--- Decision Tree Classifier ---")
print(accuracy_score(y_test, pred_dt))
print(confusion_matrix(y_test, pred_dt))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Decision Tree Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_dt), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Decision Tree Classifier ---
# 0.6842105263157895
# [[13  7]
#  [ 5 13]]

# %%
# RF

rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred_rf = rf_clf.predict(X_test)

print("\n--- Random Forest ---")
print(accuracy_score(y_test,pred_rf))
print(confusion_matrix(y_test, pred_rf))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Random Forest Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_rf), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Random Forest ---
# 0.9210526315789473
# [[18  2]
#  [ 1 17]]

# %%
# LR

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, y_train)
pred_lr = clf_lr.predict(X_test)

print("\n--- Logistic Regression Classifier ---")
print(accuracy_score(y_test, pred_lr))
print(confusion_matrix(y_test, pred_lr))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Logistic Regression Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_lr), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Logistic Regression Classifier ---
# 0.8947368421052632
# [[18  2]
#  [ 2 16]]

# %% [markdown]
# # Strong Accuracy
# ### ML (SVM: 89.4%, DT: 68.4%, RF: 92.1%, LR: 89.4%)
# ### DL (CNN: 92%, LSTM: 97%)
