acc_rw_y', 'acc_rw_z', 'gyr_rw_x', 'gyr_rw_y', 'gyr_rw_z',
#        'mag_rw_x', 'mag_rw_y', 'mag_rw_z', 'activity', 'subject'],
#       dtype='object')

# %%
features.isna().sum()
# Out:
# acc_ch_x    0
# acc_ch_y    0
# acc_ch_z    0
# acc_la_x    0
# acc_la_y    0
# acc_la_z    0
# gyr_la_x    0
# gyr_la_y    0
# gyr_la_z    0
# mag_la_x    0
# mag_la_y    0
# mag_la_z    0
# acc_rw_x    0
# acc_rw_y    0
# acc_rw_z    0
# gyr_rw_x    0
# gyr_rw_y    0
# gyr_rw_z    0
# mag_rw_x    0
# mag_rw_y    0
# mag_rw_z    0
# activity    0
# subject     0
# dtype: int64

# %%
features['activity'].value_counts()
# Out:
# 0     872550
# 1      30720
# 2      30720
# 3      30720
# 4      30720
# 9      30720
# 10     30720
# 11     30720
# 5      30720
# 7      29441
# 8      29337
# 6      28315
# 12     10342
# Name: activity, dtype: int64

# %%
activity = {
    0: 'Null',
    1: 'Standing still',
    2: 'Sitting and relaxing',
    3: 'Lying down',
    4: 'Walking',
    5: 'Climbing stairs',
    6: 'Waist bends forward',
    7: 'Frontal elevation of arms',
    8: 'Knees bending (crouching)',
    9: 'Cycling',
    10: 'Jogging',
    11: 'Running',
    12: 'Jump front & back'
}

# %%
features['activity'] = features['activity'].map(activity)

# %%
features['activity'].value_counts()
# Out:
# Null                         872550
# Standing still                30720
# Sitting and relaxing          30720
# Lying down                    30720
# Walking                       30720
# Cycling                       30720
# Jogging                       30720
# Running                       30720
# Climbing stairs               30720
# Frontal elevation of arms     29441
# Knees bending (crouching)     29337
# Waist bends forward           28315
# Jump front & back             10342
# Name: activity, dtype: int64

# %%
indexes = features[features['activity'] == 'Null'].index
features.drop(indexes , inplace=True)

# %%
features['subject'].unique()
# Out:
# array(['subject1', 'subject2', 'subject3', 'subject4', 'subject5',
#        'subject6', 'subject7', 'subject8', 'subject9', 'subject10'],
#       dtype=object)

# %%
features = features.replace({'subject':'subject1'},1)
features = features.replace({'subject':'subject2'},2)
features = features.replace({'subject':'subject3'},3)
features = features.replace({'subject':'subject4'},4)
features = features.replace({'subject':'subject5'},5)
features = features.replace({'subject':'subject6'},6)
features = features.replace({'subject':'subject7'},7)
features = features.replace({'subject':'subject8'},8)
features = features.replace({'subject':'subject9'},9)
features = features.replace({'subject':'subject10'},10)

# %%
features
# Out:
#          acc_ch_x  acc_ch_y  acc_ch_z  acc_la_x  acc_la_y  acc_la_z  gyr_la_x  \
# 6656      -9.7788   0.55690   1.19750    2.6493   -9.4517   0.37683  -0.20965
# 6657      -9.7733   0.27880   0.73036    2.4157   -9.5306   0.40179  -0.20965
# 6658      -9.8609   0.11561   0.79988    2.3865   -9.5991   0.48141  -0.20037
# 6659      -9.7409   0.17652   0.88957    2.3758   -9.5997   0.42919  -0.20037
# 6660      -9.7821   0.21637   0.90368    2.3239   -9.5406   0.40038  -0.20037
# ...           ...       ...       ...       ...       ...       ...       ...
# 1213641  -21.9470   3.92360  -6.22580   -2.4873  -19.2330   3.46140   0.61967
# 1213642  -21.9140   2.75210 -12.27900  -21.5910  -19.4370  -6.04190   0.61967
# 1213643  -21.8140  -2.72740 -12.70900    7.5433  -19.2450  -2.66800   0.61967
# 1213644  -21.7900  -3.92290  -7.27940    3.0142  -19.3340  -7.70740   0.71058
# 1213645  -14.4510  -1.67230  -4.79260   -2.3698  -19.3000  -4.23870   0.71058
#
#          gyr_la_y  gyr_la_z  mag_la_x  ...  acc_rw
#
#          gyr_la_y  gyr_la_z  mag_la_x  ...  acc_rw_z  gyr_rw_x  gyr_rw_y  \
# 6656     -0.88931  -0.50884   0.56366  ...   1.81770 -0.058824  -0.93429
# 6657     -0.88931  -0.50884   0.56810  ...   1.51890 -0.058824  -0.93429
# 6658     -0.86867  -0.50688   0.21110  ...   1.55070 -0.058824  -0.93429
# 6659     -0.86867  -0.50688   0.21565  ...   1.54130 -0.078431  -0.93429
# 6660     -0.86867  -0.50688   0.56810  ...   1.61270 -0.078431  -0.93429
# ...           ...       ...       ...  ...       ...       ...       ...
# 1213641  -0.33771  -0.82711 -18.41400  ...   2.48090 -0.437250  -1.01850
# 1213642  -0.33771  -0.82711 -26.84900  ...   3.65600 -0.437250  -1.01850
# 1213643  -0.33771  -0.82711 -30.95600  ...   4.46060 -0.437250  -1.01850
# 1213644  -0.27017  -0.75442  12.25600  ...   1.15880 -0.425490  -1.03700
# 1213645  -0.27017  -0.75442  53.97400  ...  -0.13123 -0.425490  -1.03700
#
#          gyr_rw_z   mag_rw_x  mag_rw_y  mag_rw_z           activity  subject  \
# 6656    -0.344830   0.355370  -0.37003  -0.35020     Standing still        1
# 6657    -0.344830   0.719910   0.17803   0.37363     Standing still        1
# 6658    -0.344830   0.355370  -0.37003  -0.35020     Standing still        1
# 6659    -0.340520   0.357180  -0.18858  -0.35198     Standing still        1
# 6660    -0.340520  -0.001887  -0.18867  -0.72017     Standing still        1
# ...           ...        ...       ...       ...                ...      ...
# 1213641  0.079741  -0.213000  14.60600   8.51390  Jump front & back       10
# 1213642  0.079741   8.618500  36.00000 -21.12600  Jump front & back       10
# 1213643  0.079741  16.953000   7.65350 -34.39500  Jump front & back       10
# 1213644  0.084052  25.375000 -29.79600   4.05460  Jump front & back       10
# 1213645  0.084052  12.000000  33.06100  33.12200  Jump front & back       10
#
#                     target
# 6656        Standing still
# 6657        Standing still
# 6658        Standing still
# 6659        Standing still
# 6660        Standing still
# ...                    ...
# 1213641  Jump front & back
# 1213642  Jump front & back
# 1213643  Jump front & back
# 1213644  Jump front & back
# 1213645  Jump front & back
#
# [343195 rows x 24 columns]

# %%
features.loc[features['target'].isin(['Standing still', 'Sitting and relaxing', 'Lying down']), 'target'] = 0
features.loc[features['target'].isin(['Walking', 'Climbing stairs', 'Waist bends forward', 'Frontal elevation of arms', 'Knees bending (crouching)']), 'target'] = 1
features.loc[features['target'].isin(['Cycling', 'Jogging', 'Running', 'Jump front & back']), 'target'] = 2

# %%
features
# Out:
#          acc_ch_x  acc_ch_y  acc_ch_z  acc_la_x  acc_la_y  acc_la_z  gyr_la_x  \
# 6656      -9.7788   0.55690   1.19750    2.6493   -9.4517   0.37683  -0.20965
# 6657      -9.7733   0.27880   0.73036    2.4157   -9.5306   0.40179  -0.20965
# 6658      -9.8609   0.11561   0.79988    2.3865   -9.5991   0.48141  -0.20037
# 6659      -9.7409   0.17652   0.88957    2.3758   -9.5997   0.42919  -0.20037
# 6660      -9.7821   0.21637   0.90368    2.3239   -9.5406   0.40038  -0.20037
# ...           ...       ...       ...       ...       ...       ...       ...
# 1213641  -21.9470   3.92360  -6.22580   -2.4873  -19.2330   3.46140   0.61967
# 1213642  -21.9140   2.75210 -12.27900  -21.5910  -19.4370  -6.04190   0.61967
# 1213643  -21.8140  -2.72740 -12.70900    7.5433  -19.2450  -2.66800   0.61967
# 1213644  -21.7900  -3.92290  -7.27940    3.0142  -19.3340  -7.70740   0.71058
# 1213645  -14.4510  -1.67230  -4.79260   -2.3698  -19.3000  -4.23870   0.71058
#
#          gyr_la_y  gyr_la_z  mag_la_x  ...  acc_rw_z  gyr_rw_x  gyr_rw_y  \
# 6656     -0.88931  -0.50884   0.56366  ...   1.81770 -0.058824  -0.93429
# 6657     -0.88931  -0.50884   0.56810  ...   1.51890 -0.058824  -0.93429
# 6658     -0.86867  -0.50688   0.21110  ...   1.55070 -0.058824  -0.93429
# 6659     -0.86867  -0.50688   0.21565  ...   1.54130 -0.078431  -0.93429
# 6660     -0.86867  -0.50688   0.56810  ...   1.61270 -0.078431  -0.93429
# ...           ...       ...       ...  ...       ...       ...       ...
# 1213641  -0.33771  -0.82711 -18.41400  ...   2.48090 -0.437250  -1.01850
# 1213642  -0.33771  -0.82711 -26.84900  ...   3.65600 -0.437250  -1.01850
# 1213643  -0.33771  -0.82711 -30.95600  ...   4.46060 -0.437250  -1.01850
# 1213644  -0.27017  -0.75442  12.25600  ...   1.15880 -0.425490  -1.03700
# 1213645  -0.27017  -0.75442  53.97400  ...  -0.13123 -0.425490  -1.03700
#
#          gyr_rw_z   mag_rw_x  mag_rw_y  mag_rw_z           activity  subject  \
# 6656    -0.344830   0.355370  -0.37003  -0.35020     Standing still        1
# 6657    -0.344830   0.719910   0.17803   0.37363     Standing still        1
# 6658    -0.344830   0.355370  -0.37003  -0.35020     Standing still        1
# 6659    -0.340520   0.357180  -0.18858  -0.35198     Standing still        1
# 6660    -0.340520  -0.001887  -0.18867  -0.72017     Standing still        1
# ...           ...        ...       ...       ...                ...      ...
# 1213641  0.079741  -0.213000  14.60600   8.51390  Jump front & back       10
# 1213642  0.079741   8.618500  36.00000 -21.12600  Jump front & back       10
# 1213643  0.079741  16.953000   7.65350 -34.39500  Jump front & back       10
# 1213644  0.084052  25.375000 -29.79600   4.05460  Jump front & back       10
# 1213645  0.084052  12.000000  33.06100  33.12200  Jump front & back       10
#
#          target
# 6656          0
# 6657          0
# 6658          0
# 6659          0
# 6660          0
# ...         ...
# 1213641       2
# 1213642       2
# 1213643       2
# 1213644       2
# 1213645       2
#
# [343195 rows x 24 columns]

# %% [markdown]
# ### Features

# %%
features['activity'].value_counts().plot(kind='bar', title='Training examples by activity type');

# %%
features['activity'].value_counts()
# Out:
# Standing still               30720
# Sitting and relaxing         30720
# Lying down                   30720
# Walking                      30720
# Cycling                      30720
# Jogging                      30720
# Running                      30720
# Climbing stairs              30720
# Frontal elevation of arms    29441
# Knees bending (crouching)    29337
# Waist bends forward          28315
# Jump front & back            10342
# Name: activity, dtype: int64

# %%
# The number of steps within one time segment
TIME_PERIODS = 80

# The steps to take from one segment to the next; if this value is equal to TIME_PERIODS, then there is
# no overlap between the segments
STEP_DISTANCE = 40

# %%
##x,y,z dont have the same variance so we need to scale the data 
#Standardized data:

from sklearn.preprocessing import StandardScaler

X = features[['acc_ch_y', 'acc_ch_z', 'acc_la_x', 'acc_la_y', 'acc_la_z', 'gyr_la_x',
       'gyr_la_y', 'gyr_la_z', 'mag_la_x', 'mag_la_y', 'mag_la_z', 'acc_rw_x',
       'acc_rw_y', 'acc_rw_z', 'gyr_rw_x', 'gyr_rw_y', 'gyr_rw_z', 'mag_rw_x',
       'mag_rw_y', 'mag_rw_z', 'subject']]
              
y= features['target']
              
scaler = StandardScaler()
X = scaler.fit_transform(X)

scaled_X = pd.DataFrame(data = X, columns = ['acc_ch_y', 'acc_ch_z', 'acc_la_x', 'acc_la_y', 'acc_la_z', 'gyr_la_x',
       'gyr_la_y', 'gyr_la_z', 'mag_la_x', 'mag_la_y', 'mag_la_z', 'acc_rw_x',
       'acc_rw_y', 'acc_rw_z', 'gyr_rw_x', 'gyr_rw_y', 'gyr_rw_z', 'mag_rw_x',
       'mag_rw_y', 'mag_rw_z', 'subject'])
scaled_X['label'] = y.values

scaled_X
# Out:
#         acc_ch_y  acc_ch_z  acc_la_x  acc_la_y  acc_la_z  gyr_la_x  gyr_la_y  \
# 0       0.249278  0.463206  0.200304 -0.075035  0.167061 -0.677291 -0.780659
# 1       0.149935  0.361900  0.144872 -0.090207  0.170926 -0.677291 -0.780659
# 2       0.091640  0.376976  0.137943 -0.103380  0.183256 -0.657069 -0.733180
# 3       0.113398  0.396427  0.135404 -0.103495  0.175169 -0.657069 -0.733180
# 4       0.127633  0.399487  0.123089 -0.092130  0.170708 -0.657069 -0.733180
# ...          ...       ...       ...       ...       ...       ...       ...
# 343190  1.451939 -1.146650 -1.018584 -1.955917  0.644725  1.129852  0.488203
# 343191  1.033453 -2.459379 -5.551791 -1.995145 -0.826918  1.129852  0.488203
# 343192 -0.923948 -2.552631  1.361625 -1.958224 -0.304449  1.129852  0.488203
# 343193 -1.351007 -1.375139  0.286893 -1.975338 -1.084830  1.327951  0.643568
# 343194 -0.547042 -0.835839 -0.990702 -1.968800 -0.547682  1.327951  0.643568
#
#         gyr_la_z  mag_la_x  mag_la_y  ...  acc_rw_y  acc_rw_z  gyr_rw_x  \
# 0      -0.697391  0.003087  0.050169  ... -0.498658 -0.134866  0.259770
# 1      -0.697391  0.003145  0.057905  ... -0.520396 -0.206384  0.259770
# 2      -0.693865 -0.001524  0.050243  ... -0.518831 -0.198773  0.259770
# 3      -0.693865 -0.001464  0.065715  ... -0.515805 -0.201022  0.224090
# 4      -0.693865  0.003145  0.057905  ... -0.520259 -0.183933  0.224090
# ...          ...       ...       ...  ...       ...       ...       ...
# 343190 -1.269899 -0.245108  2.038738  ...  0.124080  0.023872 -0.428874
# 343191 -1.269899 -0.355423  1.290016  ... -0.673656  0.305133 -0.428874
# 343192 -1.269899 -0.409135 -0.504116  ... -1.964555  0.497715 -0.428874
# 343193 -1.139143  0.156003  0.039967  ... -1.963491 -0.292574 -0.407474
# 343194 -1.139143  0.701602 -0.266714  ... -1.293568 -0.601344 -0.407474
#
#         gyr_rw_y  gyr_rw_z  mag_rw_x  mag_rw_y  mag_rw_z   subject  label
# 0      -0.958665 -1.406986  0.025953 -0.059176 -0.004608 -1.542374      0
# 1      -0.958665 -1.406986  0.036607 -0.041080  0.004149 -1.542374      0
# 2      -0.958665 -1.406986  0.025953 -0.059176 -0.004608 -1.542374      0
# 3      -0.958665 -1.398628  0.026005 -0.053185 -0.004629 -1.542374      0
# 4      -0.958665 -1.398628  0.015511 -0.053188 -0.009083 -1.542374      0
# ...          ...       ...       ...       ...       ...       ...    ...
# 343190 -1.112795 -0.583627  0.009341  0.435323  0.102624  1.579578      2
# 343191 -1.112795 -0.583627  0.267450  1.141741 -0.255939  1.579578      2
# 343192 -1.112795 -0.583627  0.511034  0.205756 -0.416459  1.579578      2
# 343193 -1.146656 -0.575267  0.757174 -1.030805  0.048679  1.579578      2
# 343194 -1.146656 -0.575267  0.366278  1.044696  0.400317  1.579578      2
#
# [343195 rows x 22 columns]

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
scaled_X["label"] = encoder.fit_transform(scaled_X["label"])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(scaled_X, 
                                                    scaled_X["label"],
                                                    test_size = 0.2, 
                                                    shuffle = True, 
                                                    random_state = 21)

# %%
print("X_train.shape: ", X_train.shape)
print("X_test.shape ", X_test.shape)
print("y_train.shape ", y_train.shape)
print("y_test.shape ", y_test.shape)
# Out:
# X_train.shape:  (274556, 22)
# X_test.shape  (68639, 22)
# y_train.shape  (274556,)
# y_test.shape  (68639,)

# %% [markdown]
# ### ML(SVM, DT, RF, LR)

# %% [markdown]
# ### 0 : Mild, 1 : Medium, 2 : Strong

# %%
# Classification

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
# SVM

clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)
pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("SVC Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_svm), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- SVM Classifier ---
# 0.9999854310231793
# [[18521     0     0]
#  [    0 29552     1]
#  [    0     0 20565]]

# %%
# DT

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)
pred_dt = clf_dt.predict(X_test)

print("\n--- Decision Tree Classifier ---")
print(accuracy_score(y_test, pred_dt))
print(confusion_matrix(y_test, pred_dt))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Decision Tree Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_dt), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Decision Tree Classifier ---
# 1.0
# [[18521     0     0]
#  [    0 29553     0]
#  [    0     0 20565]]

# %%
# RF

rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred_rf = rf_clf.predict(X_test)

print("\n--- Random Forest ---")
print(accuracy_score(y_test,pred_rf))
print(confusion_matrix(y_test, pred_rf))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Random Forest Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_rf), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Random Forest ---
# 1.0
# [[18521     0     0]
#  [    0 29553     0]
#  [    0     0 20565]]

# %%
# LR

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, y_train)
pred_lr = clf_lr.predict(X_test)

print("\n--- Logistic Regression Classifier ---")
print(accuracy_score(y_test, pred_lr))
print(confusion_matrix(y_test, pred_lr))

# confusion matrix

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("Logistic Regression Confusion Matrix")
sns.heatmap(confusion_matrix(y_test, pred_lr), cbar=False, linewidths=1.0, annot=True, fmt="d", cmap="Blues")
plt.show()
# Out:
# --- Logistic Regression Classifier ---
# 1.0
# [[18521     0     0]
#  [    0 29553     0]
#  [    0     0 20565]]

# %% [markdown]
# ### DL(CNN, LSTM)

# %%
from scipy import stats
import numpy as np

def create_dataset(X, y, time_steps=1, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        v = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(v)        
        ys.append(stats.mode(labels)[0][0])
       
        # Retrieve the most often used label in this segment
        
    return np.array(Xs), np.array(ys).reshape(-1, 1)

TIME_STEPS = 5
STEP = 5

X_train, y_train = create_dataset(X_train[['acc_ch_y', 'acc_ch_z', 'acc_la_x', 'acc_la_y', 'acc_la_z', 'gyr_la_x',
       'gyr_la_y', 'gyr_la_z', 'mag_la_x', 'mag_la_y', 'mag_la_z', 'acc_rw_x',
       'acc_rw_y', 'acc_rw_z', 'gyr_rw_x', 'gyr_rw_y', 'gyr_rw_z', 'mag_rw_x',
       'mag_rw_y', 'mag_rw_z', 'subject']], X_train.label, TIME_STEPS, STEP)

X_test, y_test = create_dataset(X_test[['acc_ch_y', 'acc_ch_z', 'acc_la_x', 'acc_la_y', 'acc_la_z', 'gyr_la_x',
       'gyr_la_y', 'gyr_la_z', 'mag_la_x', 'mag_la_y', 'mag_la_z', 'acc_rw_x',
       'acc_rw_y', 'acc_rw_z', 'gyr_rw_x', 'gyr_rw_y', 'gyr_rw_z', 'mag_rw_x',
       'mag_rw_y', 'mag_rw_z', 'subject']], X_test.label, TIME_STEPS, STEP)

print(X_train.shape, y_train.shape)
# Out:
# C:\Users\a0108\AppData\Local\Temp\ipykernel_8060\1322547278.py:10: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   ys.append(stats.mode(labels)[0][0])
# C:\Users\a0108\AppData\Local\Temp\ipykernel_8060\1322547278.py:10: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   ys.append(stats.mode(labels)[0][0])
# (54911, 5, 21) (54911, 1)

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown = "ignore", sparse = False)
enc = enc.fit(y_train)

y_train = enc.transform(y_train)
y_test = enc.transform(y_test)
# Out:
# C:\Users\a0108\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

from tensorflow.keras.utils import to_categorical
import tensorflow.keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D
from keras.utils import to_categorical

# %%
#Epoch 500

verbose, batch_size=1,32 

n_timesteps,n_features,n_outputs=X_train.shape[1],X_train.shape[2],y_train.shape[1]

# %%
n_timesteps,n_features,n_outputs
# Out:
# (5, 21, 3)

# %%
# Training and evaluating the LSTM model

model = keras.Sequential()
model.add(Bidirectional(LSTM(units = 128, input_shape = [X_train.shape[1], X_train.shape[2]])))
model.add(Dropout(rate = 0.5))
model.add(Dense(units = 128, activation = "relu"))
model.add(Dense(y_train.shape[1], activation = "softmax"))
model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["acc"])

# %%
history = model.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_split = 0.1, shuffle = True)
print(model.summary())
# Out:
# Epoch 1/100
# 1545/1545 [==============================] - 15s 7ms/step - loss: 0.5867 - acc: 0.7356 - val_loss: 0.4402 - val_acc: 0.8075
# Epoch 2/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.4097 - acc: 0.8227 - val_loss: 0.3496 - val_acc: 0.8512
# Epoch 3/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.3207 - acc: 0.8633 - val_loss: 0.2801 - val_acc: 0.8846
# Epoch 4/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.2554 - acc: 0.8941 - val_loss: 0.2292 - val_acc: 0.9077
# Epoch 5/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.2043 - acc: 0.9173 - val_loss: 0.2032 - val_acc: 0.9179
# Epoch 6/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.1643 - acc: 0.9353 - val_loss: 0.1783 - val_acc: 0.9321
# Epoch 7/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.1329 - acc: 0.9489 - val_loss: 0.1601 - val_acc: 0.9399
# Epoch 8/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.1055 - acc: 0.9602 - val_loss: 0.1586 - val_acc: 0.9430
# Epoch 9/100
# 1545/1545 [==============================] - 11s 7ms/step - loss: 0.0863 - acc: 0.9679 - val_loss: 0.1461 - val_acc: 0.9503
# Epoch 10/100
# 1545/1545 [==============================] - 11s 7ms/step - loss: 0.
100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0065 - acc: 0.9980 - val_loss: 0.0865 - val_acc: 0.9840
# Epoch 78/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0059 - acc: 0.9980 - val_loss: 0.0850 - val_acc: 0.9845
# Epoch 79/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0054 - acc: 0.9983 - val_loss: 0.1065 - val_acc: 0.9838
# Epoch 80/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0055 - acc: 0.9984 - val_loss: 0.1044 - val_acc: 0.9836
# Epoch 81/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0060 - acc: 0.9982 - val_loss: 0.1008 - val_acc: 0.9834
# Epoch 82/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0057 - acc: 0.9981 - val_loss: 0.1115 - val_acc: 0.9812
# Epoch 83/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0055 - acc: 0.9984 - val_loss: 0.0961 - val_acc: 0.9818
# Epoch 84/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0049 - acc: 0.9983 - val_loss: 0.0889 - val_acc: 0.9842
# Epoch 85/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0042 - acc: 0.9986 - val_loss: 0.1005 - val_acc: 0.9832
# Epoch 86/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0069 - acc: 0.9980 - val_loss: 0.0817 - val_acc: 0.9834
# Epoch 87/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0033 - acc: 0.9989 - val_loss: 0.0962 - val_acc: 0.9843
# Epoch 88/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0047 - acc: 0.9986 - val_loss: 0.1117 - val_acc: 0.9827
# Epoch 89/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0057 - acc: 0.9984 - val_loss: 0.0990 - val_acc: 0.9862
# Epoch 90/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0039 - acc: 0.9987 - val_loss: 0.0990 - val_acc: 0.9843
# Epoch 91/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0051 - acc: 0.9985 - val_loss: 0.0954 - val_acc: 0.9856
# Epoch 92/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0050 - acc: 0.9986 - val_loss: 0.1051 - val_acc: 0.9840
# Epoch 93/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0055 - acc: 0.9984 - val_loss: 0.1203 - val_acc: 0.9825
# Epoch 94/100
# 1545/1545 [==============================] - 9s 6ms/step - loss: 0.0043 - acc: 0.9987 - val_loss: 0.1164 - val_acc: 0.9816
# Epoch 95/100
# 1545/1545 [==============================] - 10s 6ms/step - loss: 0.0046 - acc: 0.9985 - val_loss: 0.1243 - val_acc: 0.9800
# Epoch 96/100
# 1545/1545 [==============================] - 10s 7ms/step - loss: 0.0051 - acc: 0.9985 - val_loss: 0.1163 - val_acc: 0.9827
# Epoch 97/100
# 1545/1545 [==============================] - 10s 7ms/step - loss: 0.0048 - acc: 0.9984 - val_loss: 0.1049 - val_acc: 0.9829
# Epoch 98/100
# 1545/1545 [==============================] - 10s 6ms/step - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0945 - val_acc: 0.9845
# Epoch 99/100
# 1545/1545 [==============================] - 10s 6ms/step - loss: 0.0060 - acc: 0.9984 - val_loss: 0.0947 - val_acc: 0.9829
# Epoch 100/100
# 1545/1545 [==============================] - 10s 6ms/step - loss: 0.0047 - acc: 0.9986 - val_loss: 0.0918 - val_acc: 0.9842
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirecti  (None, 256)               153600
#  onal)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 186883 (730.01 KB)
# Trainable params: 186883 (730.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
plt.plot(history.history["loss"], label = "train")
plt.plot(history.history["val_loss"], label = "test")
plt.legend()

# %%
model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 429/429 [==============================] - 1s 3ms/step - loss: 0.1027 - acc: 0.9843
# 429/429 [==============================] - 2s 2ms/step

# %%
from sklearn.metrics import confusion_matrix

def plot_cm(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(18, 16)) 
    ax = sns.heatmap(cm, annot = True, fmt = "d", cmap = sns.diverging_palette(220, 20, n = 7), ax = ax)

    plt.ylabel("Actual")
    plt.xlabel("Predicted")
    ax.set_xticklabels(class_names)
    ax.set_yticklabels(class_names)
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show()
    
plot_cm(enc.inverse_transform(y_test), enc.inverse_transform(y_pred), enc.categories_[0])

# %%
from sklearn.metrics import classification_report,confusion_matrix


y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# 429/429 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4595
#            1       0.99      0.99      0.99      6937
#            2       0.97      0.97      0.97      2195
#
#     accuracy                           0.98     13727
#    macro avg       0.98      0.98      0.98     13727
# weighted avg       0.98      0.98      0.98     13727
#
# [[4548   43    4]
#  [  36 6837   64]
#  [  10   59 2126]]

# %%
#CNN MODEL (Default Setting)

inputs=keras.Input(shape=(n_timesteps,n_features))

conv_1=tf.keras.layers.Conv1D(filters=64,kernel_size=5,strides=2,activation='relu')(inputs)

avg_pooling=tf.keras.layers.GlobalAveragePooling1D()(conv_1)

batch_norm=tf.keras.layers.BatchNormalization()(avg_pooling)

output=tf.keras.layers.Dense(n_outputs,activation='softmax')(batch_norm)

cmodel=tf.keras.Model(inputs=inputs,outputs=output)
cmodel.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5, 21)]           0
#
#  conv1d_1 (Conv1D)           (None, 1, 64)             6784
#
#  global_average_pooling1d_1  (None, 64)                0
#   (GlobalAveragePooling1D)
#
#  batch_normalization_1 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 7235 (28.26 KB)
# Trainable params: 7107 (27.76 KB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %%
cmodel.compile(loss='categorical_crossentropy',optimizer='RMSprop',metrics=['accuracy'])

history = cmodel.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_split = 0.1, shuffle = True)
print(cmodel.summary())
# Out:
# Epoch 1/100
# 1545/1545 [==============================] - 3s 1ms/step - loss: 0.8025 - accuracy: 0.6241 - val_loss: 0.7152 - val_accuracy: 0.6641
# Epoch 2/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.6883 - accuracy: 0.6818 - val_loss: 0.6695 - val_accuracy: 0.6914
# Epoch 3/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.6510 - accuracy: 0.7041 - val_loss: 0.6411 - val_accuracy: 0.7056
# Epoch 4/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.6224 - accuracy: 0.7160 - val_loss: 0.6310 - val_accuracy: 0.7132
# Epoch 5/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.6083 - accuracy: 0.7261 - val_loss: 0.6245 - val_accuracy: 0.7149
# Epoch 6/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5948 - accuracy: 0.7317 - val_loss: 0.6062 - val_accuracy: 0.7241
# Epoch 7/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5842 - accuracy: 0.7373 - val_loss: 0.6113 - val_accuracy: 0.7269
# Epoch 8/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5743 - accuracy: 0.7435 - val_loss: 0.6022 - val_accuracy: 0.7243
# Epoch 9/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5631 - accuracy: 0.7483 - val_loss: 0.6043 - val_accuracy: 0.7282
# Epoch 10/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5587 - accuracy: 0.7520 - val_loss: 0.5933 - val_accuracy: 0.7360
# Epoch 11/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5507 - accuracy: 0.7537 - val_loss: 0.5915 - val_accuracy: 0.7376
# Epoch 12/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5472 - accuracy: 0.7554 - val_loss: 0.5895 - val_accuracy: 0.7365
# Epoch 13/100
# 1545/1545 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7594 - val_loss: 0.5885 - val_accuracy: 0.7367
# Epoch 14/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5393 - accuracy: 0.7608 - val_loss: 0.5846 - val_accuracy: 0.7409
# Epoch 15/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5346 - accuracy: 0.7630 - val_loss: 0.5892 - val_accuracy: 0.7378
# Epoch 16/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5315 - accuracy: 0.7660 - val_loss: 0.5869 - val_accuracy: 0.7414
# Epoch 17/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5259 - accuracy: 0.7687 - val_loss: 0.5712 - val_accuracy: 0.7478
# Epoch 18/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5252 - accuracy: 0.7687 - val_loss: 0.5722 - val_accuracy: 0.7465
# Epoch 19/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.5240 - accuracy: 0.7686 - val_loss: 0.5735 - val_accuracy: 0.7487
# Epoch 20/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.
100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4619 - accuracy: 0.7999 - val_loss: 0.5537 - val_accuracy: 0.7635
# Epoch 80/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4571 - accuracy: 0.8038 - val_loss: 0.5634 - val_accuracy: 0.7600
# Epoch 81/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4611 - accuracy: 0.8001 - val_loss: 0.5635 - val_accuracy: 0.7593
# Epoch 82/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4611 - accuracy: 0.8003 - val_loss: 0.5547 - val_accuracy: 0.7611
# Epoch 83/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4567 - accuracy: 0.8022 - val_loss: 0.5661 - val_accuracy: 0.7586
# Epoch 84/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4589 - accuracy: 0.8023 - val_loss: 0.5584 - val_accuracy: 0.7578
# Epoch 85/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4583 - accuracy: 0.8027 - val_loss: 0.5514 - val_accuracy: 0.7640
# Epoch 86/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4550 - accuracy: 0.8047 - val_loss: 0.5601 - val_accuracy: 0.7589
# Epoch 87/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4597 - accuracy: 0.8024 - val_loss: 0.5610 - val_accuracy: 0.7575
# Epoch 88/100
# 1545/1545 [==============================] - 2s 2ms/step - loss: 0.4575 - accuracy: 0.8020 - val_loss: 0.5575 - val_accuracy: 0.7595
# Epoch 89/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4554 - accuracy: 0.8036 - val_loss: 0.5608 - val_accuracy: 0.7617
# Epoch 90/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4585 - accuracy: 0.8020 - val_loss: 0.5524 - val_accuracy: 0.7617
# Epoch 91/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4573 - accuracy: 0.8029 - val_loss: 0.5566 - val_accuracy: 0.7633
# Epoch 92/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4575 - accuracy: 0.8023 - val_loss: 0.5546 - val_accuracy: 0.7644
# Epoch 93/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4555 - accuracy: 0.8019 - val_loss: 0.5651 - val_accuracy: 0.7620
# Epoch 94/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4551 - accuracy: 0.8047 - val_loss: 0.5553 - val_accuracy: 0.7640
# Epoch 95/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4546 - accuracy: 0.8018 - val_loss: 0.5570 - val_accuracy: 0.7578
# Epoch 96/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4506 - accuracy: 0.8069 - val_loss: 0.5548 - val_accuracy: 0.7629
# Epoch 97/100
# 1545/1545 [==============================] - 2s 2ms/step - loss: 0.4551 - accuracy: 0.8021 - val_loss: 0.5608 - val_accuracy: 0.7567
# Epoch 98/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4524 - accuracy: 0.8050 - val_loss: 0.5615 - val_accuracy: 0.7591
# Epoch 99/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4543 - accuracy: 0.8039 - val_loss: 0.5580 - val_accuracy: 0.7635
# Epoch 100/100
# 1545/1545 [==============================] - 2s 1ms/step - loss: 0.4552 - accuracy: 0.8016 - val_loss: 0.5553 - val_accuracy: 0.7613
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5, 21)]           0
#
#  conv1d_1 (Conv1D)           (None, 1, 64)             6784
#
#  global_average_pooling1d_1  (None, 64)                0
#   (GlobalAveragePooling1D)
#
#  batch_normalization_1 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 7235 (28.26 KB)
# Trainable params: 7107 (27.76 KB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________
# None

# %%
from sklearn.metrics import classification_report,confusion_matrix


y_pred = cmodel.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# 429/429 [==============================] - 0s 965us/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.68      0.73      4595
#            1       0.77      0.82      0.79      6937
#            2       0.72      0.74      0.73      2195
#
#     accuracy                           0.76     13727
#    macro avg       0.75      0.75      0.75     13727
# weighted avg       0.76      0.76      0.76     13727
#
# [[3146 1302  147]
#  [ 758 5698  481]
#  [ 176  403 1616]]

# %% [markdown]
# ### Accuracy
# ### ML (SVM: 100%, DT: 100%, RF: 100%, LR: 99%)
# ### DL (CNN: 76%, LSTM: 98%)
